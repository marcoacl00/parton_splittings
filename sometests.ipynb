# %%
from simulator import *
# Out:
# Using device: cuda

# %%
sis = phsys(1000, 0.5, 1.5, 2) #E, z, qF, Medium size (grid)
sis.set_t(4)

# %%
X = np.linspace(-2, 2, 2048)
OSC = np.exp(1j * sis.beta(4) * X**2 ) * np.exp(-sis.eps(4) * X ** 2)

plt.plot(X, np.real(OSC))
