# %%
import sys
import os


# Add the root directory of the project to the path
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

from parton_splittings import *

# %%
sis = phsys(100, 0.3, 1.5, 1.5) #E, z, qF, Medium size (grid)
sis.set_dim(32,32,32,32) #Grid dimensions
sis.init_fsol()
ht = 0.04 #time step

# %%
simul = simulate(sis, ht, 2, 5)
# Out:
# Processing t =  0.005
# 6706.276624442523 (-0.0002020742378652115-0.02251796965094687j) 0.8995316002619532
# Number of faber coefficients =  51
# Polynomials processed
# Written  fsol_t=0.045_E=100.0GeV_q=1.5_z=0.3.npy
# 0.045
# Processing t =  0.045
# 815.315860627723 (0.00010751523403543908-0.06256683575127248j) 0.8014334335150897
# Number of faber coefficients =  86
# Polynomials processed
# 0.08499999999999999
# Processing t =  0.08499999999999999
# 462.08886869834964 (-0.0003516500456887492-0.09766385616978905j) 0.7328023850533099
# Number of faber coefficients =  54
# Polynomials processed
# 0.125
# Processing t =  0.125
# 333.1075330761852 (-3.1296181463011385e-05-0.12912267069528027j) 0.6781316067866839
# Number of faber coefficients =  42
# Polynomials processed
# 0.165
# Processing t =  0.165
# 265.7702262070803 (0.00022828728413028376-0.15773334299411879j) 0.6321881894582825
# Number of faber coefficients =  35
# Polynomials processed
# 0.20500000000000002
# Processing t =  0.20500000000000002
# 224.15106279369655 (-8.502038556260644e-05-0.18405283897137903j) 0.5923335116333194
# Number of faber coefficients =  31
# Polynomials processed
# Written  fsol_t=0.245_E=100.0GeV_q=1.5_z=0.3.npy
# 0.24500000000000002
# Processing t =  0.24500000000000002
# 195.7681140556917 (-0.000811451406380209-0.20844895035203195j) 0.5570617961011537
# Number of faber coefficients =  28
# Polynomials processed
# 0.28500000000000003
# Processing t =  0.28500000000000003
# 175.30511621393038 (8.61509945454673e-05-0.23094264480687796j) 0.5257440859513155
# Number of faber coefficients =  26
# Polynomials processed
# 0.325
# Processing t =  0.325
# 159.68502158342724 (0.00034409435339187943-0.25201184421636474j) 0.4973211260300442
# Number of faber coefficients =  25
# Polynomials processed
# 0.365
# Processing t =  0.365
# 147.33894105463128 (5.8027086035251174e-05-0.2718415716114556j) 0.47128628033898284
# Number of faber coefficients =  23
# Polynomials processed
# 0.40499999999999997
# Processing t =  0.40499999999999997
# 137.3673991451628 (-1.7430489183654082e-05-0.29046665970379043j) 0.4474042689728872
# Number of faber coefficients =  22
# Polynomials processed
# Written  fsol_t=0.445_E=100.0GeV_q=1.5_z=0.3.npy
# 0.44499999999999995
# Processing t =  0.44499999999999995
# 129.16288920941778 (0.0003828814180893636-0.3079507957688318j) 0.425445956138233
# Number of faber coefficients =  21
# Polynomials processed
# 0.48499999999999993
# Processing t =  0.48499999999999993
# 122.24020619870663 (0.00044164993159182225-0.32453785254239126j) 0.40499551780261045
# Number of faber coefficients =  21
# Polynomials processed
# 0.5249999999999999
# Processing t =  0.5249999999999999
# 116.33373486751314 (0.0005057352228559632-0.34025574223556276j) 0.3859359951632443
# Number of faber coefficients =  20
# Polynomials processed
# 0.565
# Processing t =  0.565
# 111.22928920026854 (0.0005341893054437049-0.355188663294963j) 0.36809848625591896
# Number of faber coefficients =  20
# Polynomials processed
# 0.605
# Processing t =  0.605
# 106.77009002472049 (0.0005137470470192198-0.3694066025603181j) 0.3513459995066907
# Number of faber coefficients =  19
# Polynomials processed
# Written  fsol_t=0.645_E=100.0GeV_q=1.5_z=0.3.npy
# 0.645
# Processing t =  0.645
# 102.86331984868977 (0.0008389658006884743-0.3828763879961926j) 0.3356722590921478
# Number of faber coefficients =  19
# Polynomials processed
# 0.685
# Processing t =  0.685
# 99.40641490643635 (0.001347796655682483-0.39567902116185855j) 0.32094437929724984
# Number of faber coefficients =  18
# Polynomials processed
# 0.7250000000000001
# Processing t =  0.7250000000000001
# 96.30056907771394 (0.0015859879589058064-0.4079700870562537j) 0.3069537584185265
# Number of faber coefficients =  18
# Polynomials processed
# 0.7650000000000001
# Processing t =  0.7650000000000001
# 93.46503835595318 (0.0011109925520726518-0.4199132804485556j) 0.29349310385744265
# Number of faber coefficients =  18
# Polynomials processed
# 0.8050000000000002
# Processing t =  0.8050000000000002
# 90.95043531771633 (0.0015601169524656375-0.43112168337713636j) 0.28097623835068064
# Number of faber coefficients =  17
# Polynomials processed
# Written  fsol_t=0.845_E=100.0GeV_q=1.5_z=0.3.npy
# 0.8450000000000002
# Processing t =  0.8450000000000002
# 88.62049113055598 (0.001211133479277266-0.4420835454265496j) 0.26883920073597833
# Number of faber coefficients =  17
# Polynomials processed
# 0.8850000000000002
# Processing t =  0.8850000000000002
# 86.54827790864783 (0.0019080211842948985-0.4523210785390179j) 0.2575944389252406
# Number of faber coefficients =  17
# Polynomials processed
# 0.9250000000000003
# Processing t =  0.9250000000000003
# 84.6236316871174 (0.002125689016855426-0.46228417211929673j) 0.2467322954474074
# Number of faber coefficients =  17
# Polynomials processed
# 0.9650000000000003
# Processing t =  0.9650000000000003
# 82.85519836545807 (0.002400066194543493-0.4718473141344586j) 0.23637936305303764
# Number of faber coefficients =  16
# Polynomials processed
# 1.0050000000000003
# Processing t =  1.0050000000000003
# 81.22337895469273 (0.0026981035552175094-0.4810419227214744j) 0.22649115704774805
# Number of faber coefficients =  16
# Polynomials processed
# Written  fsol_t=1.045_E=100.0GeV_q=1.5_z=0.3.npy
# 1.0450000000000004
# Processing t =  1.0450000000000004
# 79.69524660085939 (0.0026718135316995345-0.48999758004711136j) 0.2169203188066084
# Number of faber coefficients =  16
# Polynomials processed
# 1.0850000000000004
# Processing t =  1.0850000000000004
# 78.29254680667664 (0.00299352408903349-0.4985236897411569j) 0.20786257482691645
# Number of faber coefficients =  16
# Polynomials processed
# 1.1250000000000004
# Processing t =  1.1250000000000004
# 76.99694035772877 (0.0035321555393125373-0.5066735882369153j) 0.19925265148708018
# Number of faber coefficients =  16
# Polynomials processed
# 1.1650000000000005
# Processing t =  1.1650000000000005
# 75.76776550423044 (0.0036641951865787987-0.5146675863949332j) 0.19085216432312255
# Number of faber coefficients =  16
# Polynomials processed
# 1.2050000000000005
# Processing t =  1.2050000000000005
# 74.63869685325886 (0.004238279891966357-0.5222392122210175j) 0.18293554631359454
# Number of faber coefficients =  15
# Polynomials processed
# Written  fsol_t=1.245_E=100.0GeV_q=1.5_z=0.3.npy
# 1.2450000000000006
# Processing t =  1.2450000000000006
# 73.571654638108 (0.004629406576784655-0.5296106263583545j) 0.17526493668900575
# Number of faber coefficients =  15
# Polynomials processed
# 1.2850000000000006
# Processing t =  1.2850000000000006
# 72.56439112897338 (0.0049183209973219805-0.5367693977357583j) 0.16784959193274723
# Number of faber coefficients =  15
# Polynomials processed
# 1.3250000000000006
# Processing t =  1.3250000000000006
# 71.61873965711783 (0.0052601513489091475-0.5436735316374721j) 0.16072917681737967
# Number of faber coefficients =  15
# Polynomials processed
# 1.3650000000000007
# Processing t =  1.3650000000000007
# 70.72945869056028 (0.005650959110605265-0.5503345014907755j) 0.15388805650274698
# Number of faber coefficients =  15
# Polynomials processed
# 1.4050000000000007
# Processing t =  1.4050000000000007
# 69.8782876800265 (0.005793364126074291-0.5568714492387005j) 0.14720109634100056
# Number of faber coefficients =  15
# Polynomials processed
# Written  fsol_t=1.445_E=100.0GeV_q=1.5_z=0.3.npy
# 1.4450000000000007
# Processing t =  1.4450000000000007
# 69.11268813093956 (0.006800133642717586-0.5628813076648416j) 0.1410763722937841
# Number of faber coefficients =  15
# Polynomials processed
# 1.4850000000000008
# Processing t =  1.4850000000000008
# 68.35004810041406 (0.006957059953258197-0.5690099854413257j) 0.1348529649242864
# Number of faber coefficients =  15
# Polynomials processed
# 1.5250000000000008
# Processing t =  1.5250000000000008
# 67.64693760945231 (0.007564349022942283-0.5747789431939219j) 0.1290152221877564
# Number of faber coefficients =  15
# Polynomials processed
# 1.5650000000000008
# Processing t =  1.5650000000000008
# 66.97135760953715 (0.007982988991330797-0.5804380549415252j) 0.12330758196715094
# Number of faber coefficients =  15
# Polynomials processed
# 1.6050000000000009
# Processing t =  1.6050000000000009
# 66.33504436429361 (0.00852942704579265-0.5858726731350458j) 0.11784379550058656
# Number of faber coefficients =  15
# Polynomials processed
# Written  fsol_t=1.645_E=100.0GeV_q=1.5_z=0.3.npy
# 1.645000000000001
# Processing t =  1.645000000000001
# 65.72416944873814 (0.008946541962295678-0.5911903817498176j) 0.1125138755286624
# Number of faber coefficients =  14
# Polynomials processed
# 1.685000000000001
# Processing t =  1.685000000000001
# 65.14990970674894 (0.009533237851512407-0.5962788748421866j) 0.10742864014883971
# Number of faber coefficients =  14
# Polynomials processed
# 1.725000000000001
# Processing t =  1.725000000000001
# 64.59208440352661 (0.009875394899589225-0.6013107675477543j) 0.10241417441761264
# Number of faber coefficients =  14
# Polynomials processed
# 1.765000000000001
# Processing t =  1.765000000000001
# 64.07152891146708 (0.01048713368367568-0.6060831545120142j) 0.09767122423606965
# Number of faber coefficients =  14
# Polynomials processed
# 1.805000000000001
# Processing t =  1.805000000000001
# 63.572055393997374 (0.011035859829906696-0.6107363833271006j) 0.09305866922051266
# Number of faber coefficients =  14
# Polynomials processed
# Written  fsol_t=1.845_E=100.0GeV_q=1.5_z=0.3.npy
# 1.845000000000001
# Processing t =  1.845000000000001
# 63.10228030675977 (0.011754098851903115-0.615178611660842j) 0.08866618794110362
# Number of faber coefficients =  14
# Polynomials processed
# 1.8850000000000011
# Processing t =  1.8850000000000011
# 62.64695915319144 (0.012319907128837144-0.6195491931991725j) 0.08435485768407604
# Number of faber coefficients =  14
# Polynomials processed
# 1.9250000000000012
# Processing t =  1.9250000000000012
# 62.21020042147458 (0.012855834485857897-0.6238020230638776j) 0.08016940423908472
# Number of faber coefficients =  14
# Polynomials processed
# 1.9650000000000012
# Processing t =  1.9650000000000012
# 61.791085163547585 (0.013366246652848775-0.627939846662581j) 0.07610625474036242
# Number of faber coefficients =  14
# Polynomials processed
# 2.0050000000000012
