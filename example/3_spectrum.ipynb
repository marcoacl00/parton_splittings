# %%
import sys
import os


sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))
from parton_splittings import *

f_sol = np.load("saved_files/fsol_t=1.845_E=100.0GeV_q=1.5_z=0.3.npy")
sis = phsys(100, 0.3, 1.5, 1.5) #E, z, qF, Medium size (grid)
sis.set_dim(32,32,32,32) #Grid dimensions
sis.set_fsol(f_sol)
sis.set_t(1.845)

print(sis.V1)
fit = torch.load("saved_fits/fit_example.pth", weights_only=False)
fit.eval()
# Out:
# [-0.75       -0.7016129  -0.65322581 -0.60483871 -0.55645161 -0.50806452
#  -0.45967742 -0.41129032 -0.36290323 -0.31451613 -0.26612903 -0.21774194
#  -0.16935484 -0.12096774 -0.07258065 -0.02419355  0.02419355  0.07258065
#   0.12096774  0.16935484  0.21774194  0.26612903  0.31451613  0.36290323
#   0.41129032  0.45967742  0.50806452  0.55645161  0.60483871  0.65322581
#   0.7016129   0.75      ]
# simple_fitter(
#   (layers): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
Theta = np.arange(0.01, 0.12, 0.02)
Fp_an  = .0 * Theta
Fp_sim = .0 * Theta

#torch.cuda.empty_cache()
for th in range(len(Theta)):
    fp = np.real(fasit2Ncdiagint(sis.t, sis.omega*Theta[th], 0, sis.z, sis.omega, sis.Omega, sis.qhat))

    print("Computing theta = ", Theta[th])
    U1 = np.linspace(-sis.L/2, sis.L/2, 256)
    U2 = np.linspace(-sis.L/2, sis.L/2, 256)
    V1 = np.linspace(-sis.L/2, sis.L/2, 64)
    V2 = np.linspace(-sis.L/2, sis.L/2, 64)

    Fp_prime = compute_fourier_torch_chunks(fit, U1, U2, V1, V2, sis.omega*Theta[th], 0, sis.beta(sis.t), chunksize_U1=16,  chunksize_U2=8).cpu().detach().numpy()

    #Fp_prime = np.real(compute_fourier(sis.Fsol, sis.beta(sis.t), sis.U1, sis.U2, sis.V1, sis.V2, sis.omega*Theta[th], 0))

    Fp_an[th] = fp
    Fp_sim[th] = Fp_prime

    print("Analytical = ", fp)
    print("Simulation = ", Fp_prime)

# for th in range(8, len(Theta)):
#     fp = np.real(fasit2Ncdiagint(sis.t, sis.omega*Theta[th], 0, sis.z, sis.omega, sis.Omega, sis.qhat))

#     print("Computing theta = ", Theta[th])
#     U1 = np.linspace(-sis.L/2, sis.L/2, 1024)
#     U2 = np.linspace(-sis.L/2, sis.L/2, 1024)
#     V1 = np.linspace(-sis.L/4, sis.L/4, 64)
#     V2 = np.linspace(-sis.L/4, sis.L/4, 64)

#     Fp_prime = compute_fourier_torch_chunks(fit, U1, U2, V1, V2, sis.omega*Theta[th], 0, sis.beta(sis.t), chunksize_U1=16,
#       chunksize_U2=16).cpu().detach().numpy()

#     #Fp_prime = compute_fourier(sis.Fsol, sis.beta(sis.t), sis.U1, sis.U2, sis.V1, sis.V2, sis.omega*Theta[th], 0)

#     Fp_an[th] = fp
#     Fp_sim[th] = Fp_prime

#     print("Analytical = ", fp)
#     print("Simulation = ", Fp_prime)
# Out:
# Computing theta =  0.01
# Chunk  1  computed
# Chunk  2  computed
# Chunk  3  computed
# Chunk  4  computed
# Chunk  5  computed
# Chunk  6  computed
# Chunk  7  computed
# Chunk  8  computed
# Chunk  9  computed
# Chunk  10  computed
# Chunk  11  computed
# Chunk  12  computed
# Chunk  13  computed
# Chunk  14  computed
# Chunk  15  computed
# Chunk  16  computed
# Chunk  17  computed
# Chunk  18  computed
# Chunk  19  computed
# Chunk  20  computed
# Chunk  21  computed
# Chunk  22  computed
# Chunk  23  computed
# Chunk  24  computed
# Chunk  25  computed
# Chunk  26  computed
# Chunk  27  computed
# Chunk  28  computed
# Chunk  29  computed
# Chunk  30  computed
# Chunk  31  computed
# Chunk  32  computed
# Chunk  33  computed
# Chunk  34  computed
# Chunk  35  computed
# Chunk  36  computed
# Chunk  37  computed
# Chunk  38  computed
# Chunk  39  computed
# Chunk  40  computed
# Chunk  41  computed
# Chunk  42  computed
# Chunk  43  computed
# Chunk  44  computed
# Chunk  45  computed
# Chunk  46  computed
# Chunk  47  computed
# Chunk  48  computed
# Chunk  49  computed
# Chunk  50  computed
# Chunk  51  computed
# Chunk  52  computed
# Chunk  53  computed
# Chunk  54  computed
# Chunk  55  computed
# Chunk  56  computed
# Chunk  57  computed
# Chunk  58  computed
# Chunk  59  computed
# Chunk  60  computed
# Chunk  61  computed
# Chunk  62  computed
# Chunk  63  computed
# Chunk  64  computed
# Chunk  65  computed
# Chunk  66  computed
# Chunk  67  computed
# Chunk  68  computed
# Chunk  69  computed
# Chunk  70  computed
# Chunk  71  computed
# Chunk  72  computed
# Chunk  73  computed
# Chunk  74  computed
# Chunk  75  computed
# Chunk  76  computed
# Chunk  77  computed
# Chunk  78  computed
# Chunk  79  computed
# Chunk  80  computed
# Chunk  81  computed
# Chunk  82  computed
# Chunk  83  computed
# Chunk  84  computed
# Chunk  85  computed
# Chunk  86  computed
# Chunk  87  computed
# Chunk  88  computed
# Chunk  89  computed
# Chunk  90  computed
# Chunk  91  computed
# Chunk  92  computed
# Chunk  93  computed
# Chunk  94  computed
# Chunk  95  computed
# Chunk  96  computed
# Chunk  97  computed
# Chunk  98  computed
# Chunk  99  computed
# Chunk  100  computed
# Chunk  101  computed
# Chunk  102  computed
# Chunk  103  computed
# Chunk  104  computed
# Chunk  105  computed
# Chunk  106  computed
# Chunk  107  computed
# Chunk  108  computed
# Chunk  109  computed
# Chunk  110  computed
# Chunk  111  computed
# Chunk  112  computed
# Chunk  113  computed
# Chunk  114  computed
# Chunk  115  computed
# Chunk  116  computed
# Chunk  117  computed
# Chunk  118  computed
# Chunk  119  computed
# Chunk  120  computed
# Chunk  121  computed
# Chunk  122  computed
# Chunk  123  computed
# Chunk  124  computed
# Chunk  125  computed
# Chunk  126  computed
# Chunk  127  computed
# Chunk  128  computed
# Chunk  129  computed
# Chunk  130  computed
# Chunk  131  computed
# Chunk  132  computed
# Chunk  133  computed
# Chunk  134  computed
# Chunk  135  computed
# Chunk  136  computed
# Chunk  137  computed
# Chunk  138  computed
# Chunk  139  computed
# Chunk  140  computed
# Chunk  141  computed
# Chunk  142  computed
# Chunk  143  computed
# Chunk  144  computed
# Chunk  145  computed
# Chunk  146  computed
# Chunk  147  computed
# Chunk  148  computed
# Chunk  149  computed
# Chunk  150  computed
# Chunk  151  computed
# Chunk  152  computed
# Chunk  153  computed
# Chunk  154  computed
# Chunk  155  computed
# Chunk  156  computed
# Chunk  157  computed
# Chunk  158  computed
# Chunk  159  computed
# Chunk  160  computed
# Chunk  161  computed
# Chunk  162  computed
# Chunk  163  computed
# Chunk  164  computed
# Chunk  165  computed
# Chunk  166  computed
# Chunk  167  computed
# Chunk  168  computed
# Chunk  169  computed
# Chunk  170  computed
# Chunk  171  computed
# Chunk  172  computed
# Chunk  173  computed
# Chunk  174  computed
# Chunk  175  computed
# Chunk  176  computed
# Chunk  177  computed
# Chunk  178  computed
# Chunk  179  computed
# Chunk  180  computed
# Chunk  181  computed
# Chunk  182  computed
# Chunk  183  computed
# Chunk  184  computed
# Chunk  185  computed
# Chunk  186  computed
# Chunk  187  computed
# Chunk  188  computed
# Chunk  189  computed
# Chunk  190  computed
# Chunk  191  computed
# Chunk  192  computed
# Chunk  193  computed
# Chunk  194  computed
# Chunk  195  computed
# Chunk  196  computed
# Chunk  197  computed
# Chunk  198  computed
# Chunk  199  computed
# Chunk  200  computed
# Chunk  201  computed
# Chunk  202  computed
# Chunk  203  computed
# Chunk  204  computed
# Chunk  205  computed
# Chunk  206  computed
# Chunk  207  computed
# Chunk  208  computed
# Chunk  209  computed
# Chunk  210  computed
# Chunk  211  computed
# Chunk  212  computed
# Chunk  213  computed
# Chunk  214  computed
# Chunk  215  computed
# Chunk  216  computed
# Chunk  217  computed
# Chunk  218  computed
# Chunk  219  computed
# Chunk  220  computed
# Chunk  221  computed
# Chunk  222  computed
# Chunk  223  computed
# Chunk  224  computed
# Chunk  225  computed
# Chunk  226  computed
# Chunk  227  computed
# Chunk  228  computed
# Chunk  229  computed
# Chunk  230  computed
# Chunk  231  computed
# Chunk  232  computed
# Chunk  233  computed
# Chunk  234  computed
# Chunk  235  computed
# Chunk  236  computed
# Chunk  237  computed
# Chunk  238  computed
# Chunk  239  computed
# Chunk  240  computed
# Chunk  241  computed
# Chunk  242  computed
# Chunk  243  computed
# Chunk  244  computed
# Chunk  245  computed
# Chunk  246  computed
# Chunk  247  computed
# Chunk  248  computed
# Chunk  249  computed
# Chunk  250  computed
# Chunk  251  computed
# Chunk  252  computed
# Chunk  253  computed
# Chunk  254  computed
# Chunk  255  computed
# Chunk  256  computed
# Chunk  257  computed
# Chunk  258  computed
# Chunk  259  computed
# Chunk  260  computed
# Chunk  261  computed
# Chunk  262  computed
# Chunk  263  computed
# Chunk  264  computed
# Chunk  265  computed
# Chunk  266  computed
# Chunk  267  computed
# Chunk  268  computed
# Chunk  269  computed
# Chunk  270  computed
# Chunk  271  computed
# Chunk  272  computed
# Chunk  273  computed
# Chunk  274  computed
# Chunk  275  computed
# Chunk  276  computed
# Chunk  277  computed
# Chunk  278  computed
# Chunk  279  computed
# Chunk  280  computed
# Chunk  281  computed
# Chunk  282  computed
# Chunk  283  computed
# Chunk  284  computed
# Chunk  285  computed
# Chunk  286  computed
# Chunk  287  computed
# Chunk  288  computed
# Chunk  289  computed
# Chunk  290  computed
# Chunk  291  computed
# Chunk  292  computed
# Chunk  293  computed
# Chunk  294  computed
# Chunk  295  computed
# Chunk  296  computed
# Chunk  297  computed
# Chunk  298  computed
# Chunk  299  computed
# Chunk  300  computed
# Chunk  301  computed
# Chunk  302  computed
# Chunk  303  computed
# Chunk  304  computed
# Chunk  305  computed
# Chunk  306  computed
# Chunk  307  computed
# Chunk  308  computed
# Chunk  309  computed
# Chunk  310  computed
# Chunk  311  computed
# Chunk  312  computed
# Chunk  313  computed
# Chunk  314  computed
# Chunk  315  computed
# Chunk  316  computed
# Chunk  317  computed
# Chunk  318  computed
# Chunk  319  computed
# Chunk  320  computed
# Chunk  321  computed
# Chunk  322  computed
# Chunk  323  computed
# Chunk  324  computed
# Chunk  325  computed
# Chunk  326  computed
# Chunk  327  computed
# Chunk  328  computed
# Chunk  329  computed
# Chunk  330  computed
# Chunk  331  computed
# Chunk  332  computed
# Chunk  333  computed
# Chunk  334  computed
# Chunk  335  computed
# Chunk  336  computed
# Chunk  337  computed
# Chunk  338  computed
# Chunk  339  computed
# Chunk  340  computed
# Chunk  341  computed
# Chunk  342  computed
# Chunk  343  computed
# Chunk  344  computed
# Chunk  345  computed
# Chunk  346  computed
# Chunk  347  computed
# Chunk  348  computed
# Chunk  349  computed
# Chunk  350  computed
# Chunk  351  computed
# Chunk  352  computed
# Chunk  353  computed
# Chunk  354  computed
# Chunk  355  computed
# Chunk  356  computed
# Chunk  357  computed
# Chunk  358  computed
# Chunk  359  computed
# Chunk  360  computed
# Chunk  361  computed
# Chunk  362  computed
# Chunk  363  computed
# Chunk  364  computed
# Chunk  365  computed
# Chunk  366  computed
# Chunk  367  computed
# Chunk  368  computed
# Chunk  369  computed
# Chunk  370  computed
# Chunk  371  computed
# Chunk  372  computed
# Chunk  373  computed
# Chunk  374  computed
# Chunk  375  computed
# Chunk  376  computed
# Chunk  377  computed
# Chunk  378  computed
# Chunk  379  computed
# Chunk  380  computed
# Chunk  381  computed
# Chunk  382  computed
# Chunk  383  computed
# Chunk  384  computed
# Chunk  385  computed
# Chunk  386  computed
# Chunk  387  computed
# Chunk  388  computed
# Chunk  389  computed
# Chunk  390  computed
# Chunk  391  computed
# Chunk  392  computed
# Chunk  393  computed
# Chunk  394  computed
# Chunk  395  computed
# Chunk  396  computed
# Chunk  397  computed
# Chunk  398  computed
# Chunk  399  computed
# Chunk  400  computed
# Chunk  401  computed
# Chunk  402  computed
# Chunk  403  computed
# Chunk  404  computed
# Chunk  405  computed
# Chunk  406  computed
# Chunk  407  computed
# Chunk  408  computed
# Chunk  409  computed
# Chunk  410  computed
# Chunk  411  computed
# Chunk  412  computed
# Chunk  413  computed
# Chunk  414  computed
# Chunk  415  computed
# Chunk  416  computed
# Chunk  417  computed
# Chunk  418  computed
# Chunk  419  computed
# Chunk  420  computed
# Chunk  421  computed
# Chunk  422  computed
# Chunk  423  computed
# Chunk  424  computed
# Chunk  425  computed
# Chunk  426  computed
# Chunk  427  computed
# Chunk  428  computed
# Chunk  429  computed
# Chunk  430  computed
# Chunk  431  computed
# Chunk  432  computed
# Chunk  433  computed
# Chunk  434  computed
# Chunk  435  computed
# Chunk  436  computed
# Chunk  437  computed
# Chunk  438  computed
# Chunk  439  computed
# Chunk  440  computed
# Chunk  441  computed
# Chunk  442  computed
# Chunk  443  computed
# Chunk  444  computed
# Chunk  445  computed
# Chunk  446  computed
# Chunk  447  computed
# Chunk  448  computed
# Chunk  449  computed
# Chunk  450  computed
# Chunk  451  computed
# Chunk  452  computed
# Chunk  453  computed
# Chunk  454  computed
# Chunk  455  computed
# Chunk  456  computed
# Chunk  457  computed
# Chunk  458  computed
# Chunk  459  computed
# Chunk  460  computed
# Chunk  461  computed
# Chunk  462  computed
# Chunk  463  computed
# Chunk  464  computed
# Chunk  465  computed
# Chunk  466  computed
# Chunk  467  computed
# Chunk  468  computed
# Chunk  469  computed
# Chunk  470  computed
# Chunk  471  computed
# Chunk  472  computed
# Chunk  473  computed
# Chunk  474  computed
# Chunk  475  computed
# Chunk  476  computed
# Chunk  477  computed
# Chunk  478  computed
# Chunk  479  computed
# Chunk  480  computed
# Chunk  481  computed
# Chunk  482  computed
# Chunk  483  computed
# Chunk  484  computed
# Chunk  485  computed
# Chunk  486  computed
# Chunk  487  computed
# Chunk  488  computed
# Chunk  489  computed
# Chunk  490  computed
# Chunk  491  computed
# Chunk  492  computed
# Chunk  493  computed
# Chunk  494  computed
# Chunk  495  computed
# Chunk  496  computed
# Chunk  497  computed
# Chunk  498  computed
# Chunk  499  computed
# Chunk  500  computed
# Chunk  501  computed
# Chunk  502  computed
# Chunk  503  computed
# Chunk  504  computed
# Chunk  505  computed
# Chunk  506  computed
# Chunk  507  computed
# Chunk  508  computed
# Chunk  509  computed
# Chunk  510  computed
# Chunk  511  computed
# Chunk  512  computed
# Analytical =  24.73723951697733
# Simulation =  25.179607
# Computing theta =  0.03
# Chunk  1  computed
# Chunk  2  computed
# Chunk  3  computed
# Chunk  4  computed
# Chunk  5  computed
# Chunk  6  computed
# Chunk  7  computed
# Chunk  8  computed
# Chunk  9  computed
# Chunk  10  computed
# Chunk  11  computed
# Chunk  12  computed
# Chunk  13  computed
# Chunk  14  computed
# Chunk  15  computed
# Chunk  16  computed
# Chunk  17  computed
# Chunk  18  computed
# Chunk  19  computed
# Chunk  20  computed
# Chunk  21  computed
# Chunk  22  computed
# Chunk  23  computed
# Chunk  24  computed
# Chunk  25  computed
# Chunk  26  computed
# Chunk  27  computed
# Chunk  28  computed
# Chunk  29  computed
# Chunk  30  computed
# Chunk  31  computed
# Chunk  32  computed
# Chunk  33  computed
# Chunk  34  computed
# Chunk  35  computed
# Chunk  36  computed
# Chunk  37  computed
# Chunk  38  computed
# Chunk  39  computed
# Chunk  40  computed
# Chunk  41  computed
# Chunk  42  computed
# Chunk  43  computed
# Chunk  44  computed
# Chunk  45  computed
# Chunk  46  computed
# Chunk  47  computed
# Chunk  48  computed
# Chunk  49  computed
# Chunk  50  computed
# Chunk  51  computed
# Chunk  52  computed
# Chunk  53  computed
# Chunk  54  computed
# Chunk  55  computed
# Chunk  56  computed
# Chunk  57  computed
# Chunk  58  computed
# Chunk  59  computed
# Chunk  60  computed
# Chunk  61  computed
# Chunk  62  computed
# Chunk  63  computed
# Chunk  64  computed
# Chunk  65  computed
# Chunk  66  computed
# Chunk  67  computed
# Chunk  68  computed
# Chunk  69  computed
# Chunk  70  computed
# Chunk  71  computed
# Chunk  72  computed
# Chunk  73  computed
# Chunk  74  computed
# Chunk  75  computed
# Chunk  76  computed
# Chunk  77  computed
# Chunk  78  computed
# Chunk  79  computed
# Chunk  80  computed
# Chunk  81  computed
# Chunk  82  computed
# Chunk  83  computed
# Chunk  84  computed
# Chunk  85  computed
# Chunk  86  computed
# Chunk  87  computed
# Chunk  88  computed
# Chunk  89  computed
# Chunk  90  computed
# Chunk  91  computed
# Chunk  92  computed
# Chunk  93  computed
# Chunk  94  computed
# Chunk  95  computed
# Chunk  96  computed
# Chunk  97  computed
# Chunk  98  computed
# Chunk  99  computed
# Chunk  100  computed
# Chunk  101  computed
# Chunk  102  computed
# Chunk  103  computed
# Chunk  104  computed
# Chunk  105  computed
# Chunk  106  computed
# Chunk  107  computed
# Chunk  108  computed
# Chunk  109  computed
# Chunk  110  computed
# Chunk  111  computed
# Chunk  112  computed
# Chunk  113  computed
# Chunk  114  computed
# Chunk  115  computed
# Chunk  116  computed
# Chunk  117  computed
# Chunk  118  computed
# Chunk  119  computed
# Chunk  120  computed
# Chunk  121  computed
# Chunk  122  computed
# Chunk  123  computed
# Chunk  124  computed
# Chunk  125  computed
# Chunk  126  computed
# Chunk  127  computed
# Chunk  128  computed
# Chunk  129  computed
# Chunk  130  computed
# Chunk  131  computed
# Chunk  132  computed
# Chunk  133  computed
# Chunk  134  computed
# Chunk  135  computed
# Chunk  136  computed
# Chunk  137  computed
# Chunk  138  computed
# Chunk  139  computed
# Chunk  140  computed
# Chunk  141  computed
# Chunk  142  computed
# Chunk  143  computed
# Chunk  144  computed
# Chunk  145  computed
# Chunk  146  computed
# Chunk  147  computed
# Chunk  148  computed
# Chunk  149  computed
# Chunk  150  computed
# Chunk  151  computed
# Chunk  152  computed
# Chunk  153  computed
# Chunk  154  computed
# Chunk  155  computed
# Chunk  156  computed
# Chunk  157  computed
# Chunk  158  computed
# Chunk  159  computed
# Chunk  160  computed
# Chunk  161  computed
# Chunk  162  computed
# Chunk  163  computed
# Chunk  164  computed
# Chunk  165  computed
# Chunk  166  computed
# Chunk  167  computed
# Chunk  168  computed
# Chunk  169  computed
# Chunk  170  computed
# Chunk  171  computed
# Chunk  172  computed
# Chunk  173  computed
# Chunk  174  computed
# Chunk  175  computed
# Chunk  176  computed
# Chunk  177  computed
# Chunk  178  computed
# Chunk  179  computed
# Chunk  180  computed
# Chunk  181  computed
# Chunk  182  computed
# Chunk  183  computed
# Chunk  184  computed
# Chunk  185  computed
# Chunk  186  computed
# Chunk  187  computed
# Chunk  188  computed
# Chunk  189  computed
# Chunk  190  computed
# Chunk  191  computed
# Chunk  192  computed
# Chunk  193  computed
# Chunk  194  computed
# Chunk  195  computed
# Chunk  196  computed
# Chunk  197  computed
# Chunk  198  computed
# Chunk  199  computed
# Chunk  200  computed
# Chunk  201  computed
# Chunk  202  computed
# Chunk  203  computed
# Chunk  204  computed
# Chunk  205  computed
# Chunk  206  computed
# Chunk  207  computed
# Chunk  208  computed
# Chunk  209  computed
# Chunk  210  computed
# Chunk  211  computed
# Chunk  212  computed
# Chunk  213  computed
# Chunk  214  computed
# Chunk  215  computed
# Chunk  216  computed
# Chunk  217  computed
# Chunk  218  computed
# Chunk  219  computed
# Chunk  220  computed
# Chunk  221  computed
# Chunk  222  computed
# Chunk  223  computed
# Chunk  224  computed
# Chunk  225  computed
# Chunk  226  computed
# Chunk  227  computed
# Chunk  228  computed
# Chunk  229  computed
# Chunk  230  computed
# Chunk  231  computed
# Chunk  232  computed
# Chunk  233  computed
# Chunk  234  computed
# Chunk  235  computed
# Chunk  236  computed
# Chunk  237  computed
# Chunk  238  computed
# Chunk  239  computed
# Chunk  240  computed
# Chunk  241  computed
# Chunk  242  computed
# Chunk  243  computed
# Chunk  244  computed
# Chunk  245  computed
# Chunk  246  computed
# Chunk  247  computed
# Chunk  248  computed
# Chunk  249  computed
# Chunk  250  computed
# Chunk  251  computed
# Chunk  252  computed
# Chunk  253  computed
# Chunk  254  computed
# Chunk  255  computed
# Chunk  256  computed
# Chunk  257  computed
# Chunk  258  computed
# Chunk  259  computed
# Chunk  260  computed
# Chunk  261  computed
# Chunk  262  computed
# Chunk  263  computed
# Chunk  264  computed
# Chunk  265  computed
# Chunk  266  computed
# Chunk  267  computed
# Chunk  268  computed
# Chunk  269  computed
# Chunk  270  computed
# Chunk  271  computed
# Chunk  272  computed
# Chunk  273  computed
# Chunk  274  computed
# Chunk  275  computed
# Chunk  276  computed
# Chunk  277  computed
# Chunk  278  computed
# Chunk  279  computed
# Chunk  280  computed
# Chunk  281  computed
# Chunk  282  computed
# Chunk  283  computed
# Chunk  284  computed
# Chunk  285  computed
# Chunk  286  computed
# Chunk  287  computed
# Chunk  288  computed
# Chunk  289  computed
# Chunk  290  computed
# Chunk  291  computed
# Chunk  292  computed
# Chunk  293  computed
# Chunk  294  computed
# Chunk  295  computed
# Chunk  296  computed
# Chunk  297  computed
# Chunk  298  computed
# Chunk  299  computed
# Chunk  300  computed
# Chunk  301  computed
# Chunk  302  computed
# Chunk  303  computed
# Chunk  304  computed
# Chunk  305  computed
# Chunk  306  computed
# Chunk  307  computed
# Chunk  308  computed
# Chunk  309  computed
# Chunk  310  computed
# Chunk  311  computed
# Chunk  312  computed
# Chunk  313  computed
# Chunk  314  computed
# Chunk  315  computed
# Chunk  316  computed
# Chunk  317  computed
# Chunk  318  computed
# Chunk  319  computed
# Chunk  320  computed
# Chunk  321  computed
# Chunk  322  computed
# Chunk  323  computed
# Chunk  324  computed
# Chunk  325  computed
# Chunk  326  computed
# Chunk  327  computed
# Chunk  328  computed
# Chunk  329  computed
# Chunk  330  computed
# Chunk  331  computed
# Chunk  332  computed
# Chunk  333  computed
# Chunk  334  computed
# Chunk  335  computed
# Chunk  336  computed
# Chunk  337  computed
# Chunk  338  computed
# Chunk  339  computed
# Chunk  340  computed
# Chunk  341  computed
# Chunk  342  computed
# Chunk  343  computed
# Chunk  344  computed
# Chunk  345  computed
# Chunk  346  computed
# Chunk  347  computed
# Chunk  348  computed
# Chunk  349  computed
# Chunk  350  computed
# Chunk  351  computed
# Chunk  352  computed
# Chunk  353  computed
# Chunk  354  computed
# Chunk  355  computed
# Chunk  356  computed
# Chunk  357  computed
# Chunk  358  computed
# Chunk  359  computed
# Chunk  360  computed
# Chunk  361  computed
# Chunk  362  computed
# Chunk  363  computed
# Chunk  364  computed
# Chunk  365  computed
# Chunk  366  computed
# Chunk  367  computed
# Chunk  368  computed
# Chunk  369  computed
# Chunk  370  computed
# Chunk  371  computed
# Chunk  372  computed
# Chunk  373  computed
# Chunk  374  computed
# Chunk  375  computed
# Chunk  376  computed
# Chunk  377  computed
# Chunk  378  computed
# Chunk  379  computed
# Chunk  380  computed
# Chunk  381  computed
# Chunk  382  computed
# Chunk  383  computed
# Chunk  384  computed
# Chunk  385  computed
# Chunk  386  computed
# Chunk  387  computed
# Chunk  388  computed
# Chunk  389  computed
# Chunk  390  computed
# Chunk  391  computed
# Chunk  392  computed
# Chunk  393  computed
# Chunk  394  computed
# Chunk  395  computed
# Chunk  396  computed
# Chunk  397  computed
# Chunk  398  computed
# Chunk  399  computed
# Chunk  400  computed
# Chunk  401  computed
# Chunk  402  computed
# Chunk  403  computed
# Chunk  404  computed
# Chunk  405  computed
# Chunk  406  computed
# Chunk  407  computed
# Chunk  408  computed
# Chunk  409  computed
# Chunk  410  computed
# Chunk  411  computed
# Chunk  412  computed
# Chunk  413  computed
# Chunk  414  computed
# Chunk  415  computed
# Chunk  416  computed
# Chunk  417  computed
# Chunk  418  computed
# Chunk  419  computed
# Chunk  420  computed
# Chunk  421  computed
# Chunk  422  computed
# Chunk  423  computed
# Chunk  424  computed
# Chunk  425  computed
# Chunk  426  computed
# Chunk  427  computed
# Chunk  428  computed
# Chunk  429  computed
# Chunk  430  computed
# Chunk  431  computed
# Chunk  432  computed
# Chunk  433  computed
# Chunk  434  computed
# Chunk  435  computed
# Chunk  436  computed
# Chunk  437  computed
# Chunk  438  computed
# Chunk  439  computed
# Chunk  440  computed
# Chunk  441  computed
# Chunk  442  computed
# Chunk  443  computed
# Chunk  444  computed
# Chunk  445  computed
# Chunk  446  computed
# Chunk  447  computed
# Chunk  448  computed
# Chunk  449  computed
# Chunk  450  computed
# Chunk  451  computed
# Chunk  452  computed
# Chunk  453  computed
# Chunk  454  computed
# Chunk  455  computed
# Chunk  456  computed
# Chunk  457  computed
# Chunk  458  computed
# Chunk  459  computed
# Chunk  460  computed
# Chunk  461  computed
# Chunk  462  computed
# Chunk  463  computed
# Chunk  464  computed
# Chunk  465  computed
# Chunk  466  computed
# Chunk  467  computed
# Chunk  468  computed
# Chunk  469  computed
# Chunk  470  computed
# Chunk  471  computed
# Chunk  472  computed
# Chunk  473  computed
# Chunk  474  computed
# Chunk  475  computed
# Chunk  476  computed
# Chunk  477  computed
# Chunk  478  computed
# Chunk  479  computed
# Chunk  480  computed
# Chunk  481  computed
# Chunk  482  computed
# Chunk  483  computed
# Chunk  484  computed
# Chunk  485  computed
# Chunk  486  computed
# Chunk  487  computed
# Chunk  488  computed
# Chunk  489  computed
# Chunk  490  computed
# Chunk  491  computed
# Chunk  492  computed
# Chunk  493  computed
# Chunk  494  computed
# Chunk  495  computed
# Chunk  496  computed
# Chunk  497  computed
# Chunk  498  computed
# Chunk  499  computed
# Chunk  500  computed
# Chunk  501  computed
# Chunk  502  computed
# Chunk  503  computed
# Chunk  504  computed
# Chunk  505  computed
# Chunk  506  computed
# Chunk  507  computed
# Chunk  508  computed
# Chunk  509  computed
# Chunk  510  computed
# Chunk  511  computed
# Chunk  512  computed
# Analytical =  39.235198752996695
# Simulation =  43.365967
# Computing theta =  0.049999999999999996
# Chunk  1  computed
# Chunk  2  computed
# Chunk  3  computed
# Chunk  4  computed
# Chunk  5  computed
# Chunk  6  computed
# Chunk  7  computed
# Chunk  8  computed
# Chunk  9  computed
# Chunk  10  computed
# Chunk  11  computed
# Chunk  12  computed
# Chunk  13  computed
# Chunk  14  computed
# Chunk  15  computed
# Chunk  16  computed
# Chunk  17  computed
# Chunk  18  computed
# Chunk  19  computed
# Chunk  20  computed
# Chunk  21  computed
# Chunk  22  computed
# Chunk  23  computed
# Chunk  24  computed
# Chunk  25  computed
# Chunk  26  computed
# Chunk  27  computed
# Chunk  28  computed
# Chunk  29  computed
# Chunk  30  computed
# Chunk  31  computed
# Chunk  32  computed
# Chunk  33  computed
# Chunk  34  computed
# Chunk  35  computed
# Chunk  36  computed
# Chunk  37  computed
# Chunk  38  computed
# Chunk  39  computed
# Chunk  40  computed
# Chunk  41  computed
# Chunk  42  computed
# Chunk  43  computed
# Chunk  44  computed
# Chunk  45  computed
# Chunk  46  computed
# Chunk  47  computed
# Chunk  48  computed
# Chunk  49  computed
# Chunk  50  computed
# Chunk  51  computed
# Chunk  52  computed
# Chunk  53  computed
# Chunk  54  computed
# Chunk  55  computed
# Chunk  56  computed
# Chunk  57  computed
# Chunk  58  computed
# Chunk  59  computed
# Chunk  60  computed
# Chunk  61  computed
# Chunk  62  computed
# Chunk  63  computed
# Chunk  64  computed
# Chunk  65  computed
# Chunk  66  computed
# Chunk  67  computed
# Chunk  68  computed
# Chunk  69  computed
# Chunk  70  computed
# Chunk  71  computed
# Chunk  72  computed
# Chunk  73  computed
# Chunk  74  computed
# Chunk  75  computed
# Chunk  76  computed
# Chunk  77  computed
# Chunk  78  computed
# Chunk  79  computed
# Chunk  80  computed
# Chunk  81  computed
# Chunk  82  computed
# Chunk  83  computed
# Chunk  84  computed
# Chunk  85  computed
# Chunk  86  computed
# Chunk  87  computed
# Chunk  88  computed
# Chunk  89  computed
# Chunk  90  computed
# Chunk  91  computed
# Chunk  92  computed
# Chunk  93  computed
# Chunk  94  computed
# Chunk  95  computed
# Chunk  96  computed
# Chunk  97  computed
# Chunk  98  computed
# Chunk  99  computed
# Chunk  100  computed
# Chunk  101  computed
# Chunk  102  computed
# Chunk  103  computed
# Chunk  104  computed
# Chunk  105  computed
# Chunk  106  computed
# Chunk  107  computed
# Chunk  108  computed
# Chunk  109  computed
# Chunk  110  computed
# Chunk  111  computed
# Chunk  112  computed
# Chunk  113  computed
# Chunk  114  computed
# Chunk  115  computed
# Chunk  116  computed
# Chunk  117  computed
# Chunk  118  computed
# Chunk  119  computed
# Chunk  120  computed
# Chunk  121  computed
# Chunk  122  computed
# Chunk  123  computed
# Chunk  124  computed
# Chunk  125  computed
# Chunk  126  computed
# Chunk  127  computed
# Chunk  128  computed
# Chunk  129  computed
# Chunk  130  computed
# Chunk  131  computed
# Chunk  132  computed
# Chunk  133  computed
# Chunk  134  computed
# Chunk  135  computed
# Chunk  136  computed
# Chunk  137  computed
# Chunk  138  computed
# Chunk  139  computed
# Chunk  140  computed
# Chunk  141  computed
# Chunk  142  computed
# Chunk  143  computed
# Chunk  144  computed
# Chunk  145  computed
# Chunk  146  computed
# Chunk  147  computed
# Chunk  148  computed
# Chunk  149  computed
# Chunk  150  computed
# Chunk  151  computed
# Chunk  152  computed
# Chunk  153  computed
# Chunk  154  computed
# Chunk  155  computed
# Chunk  156  computed
# Chunk  157  computed
# Chunk  158  computed
# Chunk  159  computed
# Chunk  160  computed
# Chunk  161  computed
# Chunk  162  computed
# Chunk  163  computed
# Chunk  164  computed
# Chunk  165  computed
# Chunk  166  computed
# Chunk  167  computed
# Chunk  168  computed
# Chunk  169  computed
# Chunk  170  computed
# Chunk  171  computed
# Chunk  172  computed
# Chunk  173  computed
# Chunk  174  computed
# Chunk  175  computed
# Chunk  176  computed
# Chunk  177  computed
# Chunk  178  computed
# Chunk  179  computed
# Chunk  180  computed
# Chunk  181  computed
# Chunk  182  computed
# Chunk  183  computed
# Chunk  184  computed
# Chunk  185  computed
# Chunk  186  computed
# Chunk  187  computed
# Chunk  188  computed
# Chunk  189  computed
# Chunk  190  computed
# Chunk  191  computed
# Chunk  192  computed
# Chunk  193  computed
# Chunk  194  computed
# Chunk  195  computed
# Chunk  196  computed
# Chunk  197  computed
# Chunk  198  computed
# Chunk  199  computed
# Chunk  200  computed
# Chunk  201  computed
# Chunk  202  computed
# Chunk  203  computed
# Chunk  204  computed
# Chunk  205  computed
# Chunk  206  computed
# Chunk  207  computed
# Chunk  208  computed
# Chunk  209  computed
# Chunk  210  computed
# Chunk  211  computed
# Chunk  212  computed
# Chunk  213  computed
# Chunk  214  computed
# Chunk  215  computed
# Chunk  216  computed
# Chunk  217  computed
# Chunk  218  computed
# Chunk  219  computed
# Chunk  220  computed
# Chunk  221  computed
# Chunk  222  computed
# Chunk  223  computed
# Chunk  224  computed
# Chunk  225  computed
# Chunk  226  computed
# Chunk  227  computed
# Chunk  228  computed
# Chunk  229  computed
# Chunk  230  computed
# Chunk  231  computed
# Chunk  232  computed
# Chunk  233  computed
# Chunk  234  computed
# Chunk  235  computed
# Chunk  236  computed
# Chunk  237  computed
# Chunk  238  computed
# Chunk  239  computed
# Chunk  240  computed
# Chunk  241  computed
# Chunk  242  computed
# Chunk  243  computed
# Chunk  244  computed
# Chunk  245  computed
# Chunk  246  computed
# Chunk  247  computed
# Chunk  248  computed
# Chunk  249  computed
# Chunk  250  computed
# Chunk  251  computed
# Chunk  252  computed
# Chunk  253  computed
# Chunk  254  computed
# Chunk  255  computed
# Chunk  256  computed
# Chunk  257  computed
# Chunk  258  computed
# Chunk  259  computed
# Chunk  260  computed
# Chunk  261  computed
# Chunk  262  computed
# Chunk  263  computed
# Chunk  264  computed
# Chunk  265  computed
# Chunk  266  computed
# Chunk  267  computed
# Chunk  268  computed
# Chunk  269  computed
# Chunk  270  computed
# Chunk  271  computed
# Chunk  272  computed
# Chunk  273  computed
# Chunk  274  computed
# Chunk  275  computed
# Chunk  276  computed
# Chunk  277  computed
# Chunk  278  computed
# Chunk  279  computed
# Chunk  280  computed
# Chunk  281  computed
# Chunk  282  computed
# Chunk  283  computed
# Chunk  284  computed
# Chunk  285  computed
# Chunk  286  computed
# Chunk  287  computed
# Chunk  288  computed
# Chunk  289  computed
# Chunk  290  computed
# Chunk  291  computed
# Chunk  292  computed
# Chunk  293  computed
# Chunk  294  computed
# Chunk  295  computed
# Chunk  296  computed
# Chunk  297  computed
# Chunk  298  computed
# Chunk  299  computed
# Chunk  300  computed
# Chunk  301  computed
# Chunk  302  computed
# Chunk  303  computed
# Chunk  304  computed
# Chunk  305  computed
# Chunk  306  computed
# Chunk  307  computed
# Chunk  308  computed
# Chunk  309  computed
# Chunk  310  computed
# Chunk  311  computed
# Chunk  312  computed
# Chunk  313  computed
# Chunk  314  computed
# Chunk  315  computed
# Chunk  316  computed
# Chunk  317  computed
# Chunk  318  computed
# Chunk  319  computed
# Chunk  320  computed
# Chunk  321  computed
# Chunk  322  computed
# Chunk  323  computed
# Chunk  324  computed
# Chunk  325  computed
# Chunk  326  computed
# Chunk  327  computed
# Chunk  328  computed
# Chunk  329  computed
# Chunk  330  computed
# Chunk  331  computed
# Chunk  332  computed
# Chunk  333  computed
# Chunk  334  computed
# Chunk  335  computed
# Chunk  336  computed
# Chunk  337  computed
# Chunk  338  computed
# Chunk  339  computed
# Chunk  340  computed
# Chunk  341  computed
# Chunk  342  computed
# Chunk  343  computed
# Chunk  344  computed
# Chunk  345  computed
# Chunk  346  computed
# Chunk  347  computed
# Chunk  348  computed
# Chunk  349  computed
# Chunk  350  computed
# Chunk  351  computed
# Chunk  352  computed
# Chunk  353  computed
# Chunk  354  computed
# Chunk  355  computed
# Chunk  356  computed
# Chunk  357  computed
# Chunk  358  computed
# Chunk  359  computed
# Chunk  360  computed
# Chunk  361  computed
# Chunk  362  computed
# Chunk  363  computed
# Chunk  364  computed
# Chunk  365  computed
# Chunk  366  computed
# Chunk  367  computed
# Chunk  368  computed
# Chunk  369  computed
# Chunk  370  computed
# Chunk  371  computed
# Chunk  372  computed
# Chunk  373  computed
# Chunk  374  computed
# Chunk  375  computed
# Chunk  376  computed
# Chunk  377  computed
# Chunk  378  computed
# Chunk  379  computed
# Chunk  380  computed
# Chunk  381  computed
# Chunk  382  computed
# Chunk  383  computed
# Chunk  384  computed
# Chunk  385  computed
# Chunk  386  computed
# Chunk  387  computed
# Chunk  388  computed
# Chunk  389  computed
# Chunk  390  computed
# Chunk  391  computed
# Chunk  392  computed
# Chunk  393  computed
# Chunk  394  computed
# Chunk  395  computed
# Chunk  396  computed
# Chunk  397  computed
# Chunk  398  computed
# Chunk  399  computed
# Chunk  400  computed
# Chunk  401  computed
# Chunk  402  computed
# Chunk  403  computed
# Chunk  404  computed
# Chunk  405  computed
# Chunk  406  computed
# Chunk  407  computed
# Chunk  408  computed
# Chunk  409  computed
# Chunk  410  computed
# Chunk  411  computed
# Chunk  412  computed
# Chunk  413  computed
# Chunk  414  computed
# Chunk  415  computed
# Chunk  416  computed
# Chunk  417  computed
# Chunk  418  computed
# Chunk  419  computed
# Chunk  420  computed
# Chunk  421  computed
# Chunk  422  computed
# Chunk  423  computed
# Chunk  424  computed
# Chunk  425  computed
# Chunk  426  computed
# Chunk  427  computed
# Chunk  428  computed
# Chunk  429  computed
# Chunk  430  computed
# Chunk  431  computed
# Chunk  432  computed
# Chunk  433  computed
# Chunk  434  computed
# Chunk  435  computed
# Chunk  436  computed
# Chunk  437  computed
# Chunk  438  computed
# Chunk  439  computed
# Chunk  440  computed
# Chunk  441  computed
# Chunk  442  computed
# Chunk  443  computed
# Chunk  444  computed
# Chunk  445  computed
# Chunk  446  computed
# Chunk  447  computed
# Chunk  448  computed
# Chunk  449  computed
# Chunk  450  computed
# Chunk  451  computed
# Chunk  452  computed
# Chunk  453  computed
# Chunk  454  computed
# Chunk  455  computed
# Chunk  456  computed
# Chunk  457  computed
# Chunk  458  computed
# Chunk  459  computed
# Chunk  460  computed
# Chunk  461  computed
# Chunk  462  computed
# Chunk  463  computed
# Chunk  464  computed
# Chunk  465  computed
# Chunk  466  computed
# Chunk  467  computed
# Chunk  468  computed
# Chunk  469  computed
# Chunk  470  computed
# Chunk  471  computed
# Chunk  472  computed
# Chunk  473  computed
# Chunk  474  computed
# Chunk  475  computed
# Chunk  476  computed
# Chunk  477  computed
# Chunk  478  computed
# Chunk  479  computed
# Chunk  480  computed
# Chunk  481  computed
# Chunk  482  computed
# Chunk  483  computed
# Chunk  484  computed
# Chunk  485  computed
# Chunk  486  computed
# Chunk  487  computed
# Chunk  488  computed
# Chunk  489  computed
# Chunk  490  computed
# Chunk  491  computed
# Chunk  492  computed
# Chunk  493  computed
# Chunk  494  computed
# Chunk  495  computed
# Chunk  496  computed
# Chunk  497  computed
# Chunk  498  computed
# Chunk  499  computed
# Chunk  500  computed
# Chunk  501  computed
# Chunk  502  computed
# Chunk  503  computed
# Chunk  504  computed
# Chunk  505  computed
# Chunk  506  computed
# Chunk  507  computed
# Chunk  508  computed
# Chunk  509  computed
# Chunk  510  computed
# Chunk  511  computed
# Chunk  512  computed
# Analytical =  67.17719153326615
# Simulation =  47.369408
# Computing theta =  0.06999999999999999
# Chunk  1  computed
# Chunk  2  computed
# Chunk  3  computed
# Chunk  4  computed
# Chunk  5  computed
# Chunk  6  computed
# Chunk  7  computed
# Chunk  8  computed
# Chunk  9  computed
# Chunk  10  computed
# Chunk  11  computed
# Chunk  12  computed
# Chunk  13  computed
# Chunk  14  computed
# Chunk  15  computed
# Chunk  16  computed
# Chunk  17  computed
# Chunk  18  computed
# Chunk  19  computed
# Chunk  20  computed
# Chunk  21  computed
# Chunk  22  computed
# Chunk  23  computed
# Chunk  24  computed
# Chunk  25  computed
# Chunk  26  computed
# Chunk  27  computed
# Chunk  28  computed
# Chunk  29  computed
# Chunk  30  computed
# Chunk  31  computed
# Chunk  32  computed
# Chunk  33  computed
# Chunk  34  computed
# Chunk  35  computed
# Chunk  36  computed
# Chunk  37  computed
# Chunk  38  computed
# Chunk  39  computed
# Chunk  40  computed
# Chunk  41  computed
# Chunk  42  computed
# Chunk  43  computed
# Chunk  44  computed
# Chunk  45  computed
# Chunk  46  computed
# Chunk  47  computed
# Chunk  48  computed
# Chunk  49  computed
# Chunk  50  computed
# Chunk  51  computed
# Chunk  52  computed
# Chunk  53  computed
# Chunk  54  computed
# Chunk  55  computed
# Chunk  56  computed
# Chunk  57  computed
# Chunk  58  computed
# Chunk  59  computed
# Chunk  60  computed
# Chunk  61  computed
# Chunk  62  computed
# Chunk  63  computed
# Chunk  64  computed
# Chunk  65  computed
# Chunk  66  computed
# Chunk  67  computed
# Chunk  68  computed
# Chunk  69  computed
# Chunk  70  computed
# Chunk  71  computed
# Chunk  72  computed
# Chunk  73  computed
# Chunk  74  computed
# Chunk  75  computed
# Chunk  76  computed
# Chunk  77  computed
# Chunk  78  computed
# Chunk  79  computed
# Chunk  80  computed
# Chunk  81  computed
# Chunk  82  computed
# Chunk  83  computed
# Chunk  84  computed
# Chunk  85  computed
# Chunk  86  computed
# Chunk  87  computed
# Chunk  88  computed
# Chunk  89  computed
# Chunk  90  computed
# Chunk  91  computed
# Chunk  92  computed
# Chunk  93  computed
# Chunk  94  computed
# Chunk  95  computed
# Chunk  96  computed
# Chunk  97  computed
# Chunk  98  computed
# Chunk  99  computed
# Chunk  100  computed
# Chunk  101  computed
# Chunk  102  computed
# Chunk  103  computed
# Chunk  104  computed
# Chunk  105  computed
# Chunk  106  computed
# Chunk  107  computed
# Chunk  108  computed
# Chunk  109  computed
# Chunk  110  computed
# Chunk  111  computed
# Chunk  112  computed
# Chunk  113  computed
# Chunk  114  computed
# Chunk  115  computed
# Chunk  116  computed
# Chunk  117  computed
# Chunk  118  computed
# Chunk  119  computed
# Chunk  120  computed
# Chunk  121  computed
# Chunk  122  computed
# Chunk  123  computed
# Chunk  124  computed
# Chunk  125  computed
# Chunk  126  computed
# Chunk  127  computed
# Chunk  128  computed
# Chunk  129  computed
# Chunk  130  computed
# Chunk  131  computed
# Chunk  132  computed
# Chunk  133  computed
# Chunk  134  computed
# Chunk  135  computed
# Chunk  136  computed
# Chunk  137  computed
# Chunk  138  computed
# Chunk  139  computed
# Chunk  140  computed
# Chunk  141  computed
# Chunk  142  computed
# Chunk  143  computed
# Chunk  144  computed
# Chunk  145  computed
# Chunk  146  computed
# Chunk  147  computed
# Chunk  148  computed
# Chunk  149  computed
# Chunk  150  computed
# Chunk  151  computed
# Chunk  152  computed
# Chunk  153  computed
# Chunk  154  computed
# Chunk  155  computed
# Chunk  156  computed
# Chunk  157  computed
# Chunk  158  computed
# Chunk  159  computed
# Chunk  160  computed
# Chunk  161  computed
# Chunk  162  computed
# Chunk  163  computed
# Chunk  164  computed
# Chunk  165  computed
# Chunk  166  computed
# Chunk  167  computed
# Chunk  168  computed
# Chunk  169  computed
# Chunk  170  computed
# Chunk  171  computed
# Chunk  172  computed
# Chunk  173  computed
# Chunk  174  computed
# Chunk  175  computed
# Chunk  176  computed
# Chunk  177  computed
# Chunk  178  computed
# Chunk  179  computed
# Chunk  180  computed
# Chunk  181  computed
# Chunk  182  computed
# Chunk  183  computed
# Chunk  184  computed
# Chunk  185  computed
# Chunk  186  computed
# Chunk  187  computed
# Chunk  188  computed
# Chunk  189  computed
# Chunk  190  computed
# Chunk  191  computed
# Chunk  192  computed
# Chunk  193  computed
# Chunk  194  computed
# Chunk  195  computed
# Chunk  196  computed
# Chunk  197  computed
# Chunk  198  computed
# Chunk  199  computed
# Chunk  200  computed
# Chunk  201  computed
# Chunk  202  computed
# Chunk  203  computed
# Chunk  204  computed
# Chunk  205  computed
# Chunk  206  computed
# Chunk  207  computed
# Chunk  208  computed
# Chunk  209  computed
# Chunk  210  computed
# Chunk  211  computed
# Chunk  212  computed
# Chunk  213  computed
# Chunk  214  computed
# Chunk  215  computed
# Chunk  216  computed
# Chunk  217  computed
# Chunk  218  computed
# Chunk  219  computed
# Chunk  220  computed
# Chunk  221  computed
# Chunk  222  computed
# Chunk  223  computed
# Chunk  224  computed
# Chunk  225  computed
# Chunk  226  computed
# Chunk  227  computed
# Chunk  228  computed
# Chunk  229  computed
# Chunk  230  computed
# Chunk  231  computed
# Chunk  232  computed
# Chunk  233  computed
# Chunk  234  computed
# Chunk  235  computed
# Chunk  236  computed
# Chunk  237  computed
# Chunk  238  computed
# Chunk  239  computed
# Chunk  240  computed
# Chunk  241  computed
# Chunk  242  computed
# Chunk  243  computed
# Chunk  244  computed
# Chunk  245  computed
# Chunk  246  computed
# Chunk  247  computed
# Chunk  248  computed
# Chunk  249  computed
# Chunk  250  computed
# Chunk  251  computed
# Chunk  252  computed
# Chunk  253  computed
# Chunk  254  computed
# Chunk  255  computed
# Chunk  256  computed
# Chunk  257  computed
# Chunk  258  computed
# Chunk  259  computed
# Chunk  260  computed
# Chunk  261  computed
# Chunk  262  computed
# Chunk  263  computed
# Chunk  264  computed
# Chunk  265  computed
# Chunk  266  computed
# Chunk  267  computed
# Chunk  268  computed
# Chunk  269  computed
# Chunk  270  computed
# Chunk  271  computed
# Chunk  272  computed
# Chunk  273  computed
# Chunk  274  computed
# Chunk  275  computed
# Chunk  276  computed
# Chunk  277  computed
# Chunk  278  computed
# Chunk  279  computed
# Chunk  280  computed
# Chunk  281  computed
# Chunk  282  computed
# Chunk  283  computed
# Chunk  284  computed
# Chunk  285  computed
# Chunk  286  computed
# Chunk  287  computed
# Chunk  288  computed
# Chunk  289  computed
# Chunk  290  computed
# Chunk  291  computed
# Chunk  292  computed
# Chunk  293  computed
# Chunk  294  computed
# Chunk  295  computed
# Chunk  296  computed
# Chunk  297  computed
# Chunk  298  computed
# Chunk  299  computed
# Chunk  300  computed
# Chunk  301  computed
# Chunk  302  computed
# Chunk  303  computed
# Chunk  304  computed
# Chunk  305  computed
# Chunk  306  computed
# Chunk  307  computed
# Chunk  308  computed
# Chunk  309  computed
# Chunk  310  computed
# Chunk  311  computed
# Chunk  312  computed
# Chunk  313  computed
# Chunk  314  computed
# Chunk  315  computed
# Chunk  316  computed
# Chunk  317  computed
# Chunk  318  computed
# Chunk  319  computed
# Chunk  320  computed
# Chunk  321  computed
# Chunk  322  computed
# Chunk  323  computed
# Chunk  324  computed
# Chunk  325  computed
# Chunk  326  computed
# Chunk  327  computed
# Chunk  328  computed
# Chunk  329  computed
# Chunk  330  computed
# Chunk  331  computed
# Chunk  332  computed
# Chunk  333  computed
# Chunk  334  computed
# Chunk  335  computed
# Chunk  336  computed
# Chunk  337  computed
# Chunk  338  computed
# Chunk  339  computed
# Chunk  340  computed
# Chunk  341  computed
# Chunk  342  computed
# Chunk  343  computed
# Chunk  344  computed
# Chunk  345  computed
# Chunk  346  computed
# Chunk  347  computed
# Chunk  348  computed
# Chunk  349  computed
# Chunk  350  computed
# Chunk  351  computed
# Chunk  352  computed
# Chunk  353  computed
# Chunk  354  computed
# Chunk  355  computed
# Chunk  356  computed
# Chunk  357  computed
# Chunk  358  computed
# Chunk  359  computed
# Chunk  360  computed
# Chunk  361  computed
# Chunk  362  computed
# Chunk  363  computed
# Chunk  364  computed
# Chunk  365  computed
# Chunk  366  computed
# Chunk  367  computed
# Chunk  368  computed
# Chunk  369  computed
# Chunk  370  computed
# Chunk  371  computed
# Chunk  372  computed
# Chunk  373  computed
# Chunk  374  computed
# Chunk  375  computed
# Chunk  376  computed
# Chunk  377  computed
# Chunk  378  computed
# Chunk  379  computed
# Chunk  380  computed
# Chunk  381  computed
# Chunk  382  computed
# Chunk  383  computed
# Chunk  384  computed
# Chunk  385  computed
# Chunk  386  computed
# Chunk  387  computed
# Chunk  388  computed
# Chunk  389  computed
# Chunk  390  computed
# Chunk  391  computed
# Chunk  392  computed
# Chunk  393  computed
# Chunk  394  computed
# Chunk  395  computed
# Chunk  396  computed
# Chunk  397  computed
# Chunk  398  computed
# Chunk  399  computed
# Chunk  400  computed
# Chunk  401  computed
# Chunk  402  computed
# Chunk  403  computed
# Chunk  404  computed
# Chunk  405  computed
# Chunk  406  computed
# Chunk  407  computed
# Chunk  408  computed
# Chunk  409  computed
# Chunk  410  computed
# Chunk  411  computed
# Chunk  412  computed
# Chunk  413  computed
# Chunk  414  computed
# Chunk  415  computed
# Chunk  416  computed
# Chunk  417  computed
# Chunk  418  computed
# Chunk  419  computed
# Chunk  420  computed
# Chunk  421  computed
# Chunk  422  computed
# Chunk  423  computed
# Chunk  424  computed
# Chunk  425  computed
# Chunk  426  computed
# Chunk  427  computed
# Chunk  428  computed
# Chunk  429  computed
# Chunk  430  computed
# Chunk  431  computed
# Chunk  432  computed
# Chunk  433  computed
# Chunk  434  computed
# Chunk  435  computed
# Chunk  436  computed
# Chunk  437  computed
# Chunk  438  computed
# Chunk  439  computed
# Chunk  440  computed
# Chunk  441  computed
# Chunk  442  computed
# Chunk  443  computed
# Chunk  444  computed
# Chunk  445  computed
# Chunk  446  computed
# Chunk  447  computed
# Chunk  448  computed
# Chunk  449  computed
# Chunk  450  computed
# Chunk  451  computed
# Chunk  452  computed
# Chunk  453  computed
# Chunk  454  computed
# Chunk  455  computed
# Chunk  456  computed
# Chunk  457  computed
# Chunk  458  computed
# Chunk  459  computed
# Chunk  460  computed
# Chunk  461  computed
# Chunk  462  computed
# Chunk  463  computed
# Chunk  464  computed
# Chunk  465  computed
# Chunk  466  computed
# Chunk  467  computed
# Chunk  468  computed
# Chunk  469  computed
# Chunk  470  computed
# Chunk  471  computed
# Chunk  472  computed
# Chunk  473  computed
# Chunk  474  computed
# Chunk  475  computed
# Chunk  476  computed
# Chunk  477  computed
# Chunk  478  computed
# Chunk  479  computed
# Chunk  480  computed
# Chunk  481  computed
# Chunk  482  computed
# Chunk  483  computed
# Chunk  484  computed
# Chunk  485  computed
# Chunk  486  computed
# Chunk  487  computed
# Chunk  488  computed
# Chunk  489  computed
# Chunk  490  computed
# Chunk  491  computed
# Chunk  492  computed
# Chunk  493  computed
# Chunk  494  computed
# Chunk  495  computed
# Chunk  496  computed
# Chunk  497  computed
# Chunk  498  computed
# Chunk  499  computed
# Chunk  500  computed
# Chunk  501  computed
# Chunk  502  computed
# Chunk  503  computed
# Chunk  504  computed
# Chunk  505  computed
# Chunk  506  computed
# Chunk  507  computed
# Chunk  508  computed
# Chunk  509  computed
# Chunk  510  computed
# Chunk  511  computed
# Chunk  512  computed
# Analytical =  105.98380390577435
# Simulation =  57.043056
# Computing theta =  0.08999999999999998
# Chunk  1  computed
# Chunk  2  computed
# Chunk  3  computed
# Chunk  4  computed
# Chunk  5  computed
# Chunk  6  computed
# Chunk  7  computed
# Chunk  8  computed
# Chunk  9  computed
# Chunk  10  computed
# Chunk  11  computed
# Chunk  12  computed
# Chunk  13  computed
# Chunk  14  computed
# Chunk  15  computed
# Chunk  16  computed
# Chunk  17  computed
# Chunk  18  computed
# Chunk  19  computed
# Chunk  20  computed
# Chunk  21  computed
# Chunk  22  computed
# Chunk  23  computed
# Chunk  24  computed
# Chunk  25  computed
# Chunk  26  computed
# Chunk  27  computed
# Chunk  28  computed
# Chunk  29  computed
# Chunk  30  computed
# Chunk  31  computed
# Chunk  32  computed
# Chunk  33  computed
# Chunk  34  computed
# Chunk  35  computed
# Chunk  36  computed
# Chunk  37  computed
# Chunk  38  computed
# Chunk  39  computed
# Chunk  40  computed
# Chunk  41  computed
# Chunk  42  computed
# Chunk  43  computed
# Chunk  44  computed
# Chunk  45  computed
# Chunk  46  computed
# Chunk  47  computed
# Chunk  48  computed
# Chunk  49  computed
# Chunk  50  computed
# Chunk  51  computed
# Chunk  52  computed
# Chunk  53  computed
# Chunk  54  computed
# Chunk  55  computed
# Chunk  56  computed
# Chunk  57  computed
# Chunk  58  computed
# Chunk  59  computed
# Chunk  60  computed
# Chunk  61  computed
# Chunk  62  computed
# Chunk  63  computed
# Chunk  64  computed
# Chunk  65  computed
# Chunk  66  computed
# Chunk  67  computed
# Chunk  68  computed
# Chunk  69  computed
# Chunk  70  computed
# Chunk  71  computed
# Chunk  72  computed
# Chunk  73  computed
# Chunk  74  computed
# Chunk  75  computed
# Chunk  76  computed
# Chunk  77  computed
# Chunk  78  computed
# Chunk  79  computed
# Chunk  80  computed
# Chunk  81  computed
# Chunk  82  computed
# Chunk  83  computed
# Chunk  84  computed
# Chunk  85  computed
# Chunk  86  computed
# Chunk  87  computed
# Chunk  88  computed
# Chunk  89  computed
# Chunk  90  computed
# Chunk  91  computed
# Chunk  92  computed
# Chunk  93  computed
# Chunk  94  computed
# Chunk  95  computed
# Chunk  96  computed
# Chunk  97  computed
# Chunk  98  computed
# Chunk  99  computed
# Chunk  100  computed
# Chunk  101  computed
# Chunk  102  computed
# Chunk  103  computed
# Chunk  104  computed
# Chunk  105  computed
# Chunk  106  computed
# Chunk  107  computed
# Chunk  108  computed
# Chunk  109  computed
# Chunk  110  computed
# Chunk  111  computed
# Chunk  112  computed
# Chunk  113  computed
# Chunk  114  computed
# Chunk  115  computed
# Chunk  116  computed
# Chunk  117  computed
# Chunk  118  computed
# Chunk  119  computed
# Chunk  120  computed
# Chunk  121  computed
# Chunk  122  computed
# Chunk  123  computed
# Chunk  124  computed
# Chunk  125  computed
# Chunk  126  computed
# Chunk  127  computed
# Chunk  128  computed
# Chunk  129  computed
# Chunk  130  computed
# Chunk  131  computed
# Chunk  132  computed
# Chunk  133  computed
# Chunk  134  computed
# Chunk  135  computed
# Chunk  136  computed
# Chunk  137  computed
# Chunk  138  computed
# Chunk  139  computed
# Chunk  140  computed
# Chunk  141  computed
# Chunk  142  computed
# Chunk  143  computed
# Chunk  144  computed
# Chunk  145  computed
# Chunk  146  computed
# Chunk  147  computed
# Chunk  148  computed
# Chunk  149  computed
# Chunk  150  computed
# Chunk  151  computed
# Chunk  152  computed
# Chunk  153  computed
# Chunk  154  computed
# Chunk  155  computed
# Chunk  156  computed
# Chunk  157  computed
# Chunk  158  computed
# Chunk  159  computed
# Chunk  160  computed
# Chunk  161  computed
# Chunk  162  computed
# Chunk  163  computed
# Chunk  164  computed
# Chunk  165  computed
# Chunk  166  computed
# Chunk  167  computed
# Chunk  168  computed
# Chunk  169  computed
# Chunk  170  computed
# Chunk  171  computed
# Chunk  172  computed
# Chunk  173  computed
# Chunk  174  computed
# Chunk  175  computed
# Chunk  176  computed
# Chunk  177  computed
# Chunk  178  computed
# Chunk  179  computed
# Chunk  180  computed
# Chunk  181  computed
# Chunk  182  computed
# Chunk  183  computed
# Chunk  184  computed
# Chunk  185  computed
# Chunk  186  computed
# Chunk  187  computed
# Chunk  188  computed
# Chunk  189  computed
# Chunk  190  computed
# Chunk  191  computed
# Chunk  192  computed
# Chunk  193  computed
# Chunk  194  computed
# Chunk  195  computed
# Chunk  196  computed
# Chunk  197  computed
# Chunk  198  computed
# Chunk  199  computed
# Chunk  200  computed
# Chunk  201  computed
# Chunk  202  computed
# Chunk  203  computed
# Chunk  204  computed
# Chunk  205  computed
# Chunk  206  computed
# Chunk  207  computed
# Chunk  208  computed
# Chunk  209  computed
# Chunk  210  computed
# Chunk  211  computed
# Chunk  212  computed
# Chunk  213  computed
# Chunk  214  computed
# Chunk  215  computed
# Chunk  216  computed
# Chunk  217  computed
# Chunk  218  computed
# Chunk  219  computed
# Chunk  220  computed
# Chunk  221  computed
# Chunk  222  computed
# Chunk  223  computed
# Chunk  224  computed
# Chunk  225  computed
# Chunk  226  computed
# Chunk  227  computed
# Chunk  228  computed
# Chunk  229  computed
# Chunk  230  computed
# Chunk  231  computed
# Chunk  232  computed
# Chunk  233  computed
# Chunk  234  computed
# Chunk  235  computed
# Chunk  236  computed
# Chunk  237  computed
# Chunk  238  computed
# Chunk  239  computed
# Chunk  240  computed
# Chunk  241  computed
# Chunk  242  computed
# Chunk  243  computed
# Chunk  244  computed
# ...
# Chunk  266  computed
# Chunk  267  computed
# Chunk  268  computed
# Chunk  269  computed
# Chunk  270  computed
# Chunk  271  computed
# Chunk  272  computed
# Chunk  273  computed
# Chunk  274  computed
# Chunk  275  computed
# Chunk  276  computed
# Chunk  277  computed
# Chunk  278  computed
# Chunk  279  computed
# Chunk  280  computed
# Chunk  281  computed
# Chunk  282  computed
# Chunk  283  computed
# Chunk  284  computed
# Chunk  285  computed
# Chunk  286  computed
# Chunk  287  computed
# Chunk  288  computed
# Chunk  289  computed
# Chunk  290  computed
# Chunk  291  computed
# Chunk  292  computed
# Chunk  293  computed
# Chunk  294  computed
# Chunk  295  computed
# Chunk  296  computed
# Chunk  297  computed
# Chunk  298  computed
# Chunk  299  computed
# Chunk  300  computed
# Chunk  301  computed
# Chunk  302  computed
# Chunk  303  computed
# Chunk  304  computed
# Chunk  305  computed
# Chunk  306  computed
# Chunk  307  computed
# Chunk  308  computed
# Chunk  309  computed
# Chunk  310  computed
# Chunk  311  computed
# Chunk  312  computed
# Chunk  313  computed
# Chunk  314  computed
# Chunk  315  computed
# Chunk  316  computed
# Chunk  317  computed
# Chunk  318  computed
# Chunk  319  computed
# Chunk  320  computed
# Chunk  321  computed
# Chunk  322  computed
# Chunk  323  computed
# Chunk  324  computed
# Chunk  325  computed
# Chunk  326  computed
# Chunk  327  computed
# Chunk  328  computed
# Chunk  329  computed
# Chunk  330  computed
# Chunk  331  computed
# Chunk  332  computed
# Chunk  333  computed
# Chunk  334  computed
# Chunk  335  computed
# Chunk  336  computed
# Chunk  337  computed
# Chunk  338  computed
# Chunk  339  computed
# Chunk  340  computed
# Chunk  341  computed
# Chunk  342  computed
# Chunk  343  computed
# Chunk  344  computed
# Chunk  345  computed
# Chunk  346  computed
# Chunk  347  computed
# Chunk  348  computed
# Chunk  349  computed
# Chunk  350  computed
# Chunk  351  computed
# Chunk  352  computed
# Chunk  353  computed
# Chunk  354  computed
# Chunk  355  computed
# Chunk  356  computed
# Chunk  357  computed
# Chunk  358  computed
# Chunk  359  computed
# Chunk  360  computed
# Chunk  361  computed
# Chunk  362  computed
# Chunk  363  computed
# Chunk  364  computed
# Chunk  365  computed
# Chunk  366  computed
# Chunk  367  computed
# Chunk  368  computed
# Chunk  369  computed
# Chunk  370  computed
# Chunk  371  computed
# Chunk  372  computed
# Chunk  373  computed
# Chunk  374  computed
# Chunk  375  computed
# Chunk  376  computed
# Chunk  377  computed
# Chunk  378  computed
# Chunk  379  computed
# Chunk  380  computed
# Chunk  381  computed
# Chunk  382  computed
# Chunk  383  computed
# Chunk  384  computed
# Chunk  385  computed
# Chunk  386  computed
# Chunk  387  computed
# Chunk  388  computed
# Chunk  389  computed
# Chunk  390  computed
# Chunk  391  computed
# Chunk  392  computed
# Chunk  393  computed
# Chunk  394  computed
# Chunk  395  computed
# Chunk  396  computed
# Chunk  397  computed
# Chunk  398  computed
# Chunk  399  computed
# Chunk  400  computed
# Chunk  401  computed
# Chunk  402  computed
# Chunk  403  computed
# Chunk  404  computed
# Chunk  405  computed
# Chunk  406  computed
# Chunk  407  computed
# Chunk  408  computed
# Chunk  409  computed
# Chunk  410  computed
# Chunk  411  computed
# Chunk  412  computed
# Chunk  413  computed
# Chunk  414  computed
# Chunk  415  computed
# Chunk  416  computed
# Chunk  417  computed
# Chunk  418  computed
# Chunk  419  computed
# Chunk  420  computed
# Chunk  421  computed
# Chunk  422  computed
# Chunk  423  computed
# Chunk  424  computed
# Chunk  425  computed
# Chunk  426  computed
# Chunk  427  computed
# Chunk  428  computed
# Chunk  429  computed
# Chunk  430  computed
# Chunk  431  computed
# Chunk  432  computed
# Chunk  433  computed
# Chunk  434  computed
# Chunk  435  computed
# Chunk  436  computed
# Chunk  437  computed
# Chunk  438  computed
# Chunk  439  computed
# Chunk  440  computed
# Chunk  441  computed
# Chunk  442  computed
# Chunk  443  computed
# Chunk  444  computed
# Chunk  445  computed
# Chunk  446  computed
# Chunk  447  computed
# Chunk  448  computed
# Chunk  449  computed
# Chunk  450  computed
# Chunk  451  computed
# Chunk  452  computed
# Chunk  453  computed
# Chunk  454  computed
# Chunk  455  computed
# Chunk  456  computed
# Chunk  457  computed
# Chunk  458  computed
# Chunk  459  computed
# Chunk  460  computed
# Chunk  461  computed
# Chunk  462  computed
# Chunk  463  computed
# Chunk  464  computed
# Chunk  465  computed
# Chunk  466  computed
# Chunk  467  computed
# Chunk  468  computed
# Chunk  469  computed
# Chunk  470  computed
# Chunk  471  computed
# Chunk  472  computed
# Chunk  473  computed
# Chunk  474  computed
# Chunk  475  computed
# Chunk  476  computed
# Chunk  477  computed
# Chunk  478  computed
# Chunk  479  computed
# Chunk  480  computed
# Chunk  481  computed
# Chunk  482  computed
# Chunk  483  computed
# Chunk  484  computed
# Chunk  485  computed
# Chunk  486  computed
# Chunk  487  computed
# Chunk  488  computed
# Chunk  489  computed
# Chunk  490  computed
# Chunk  491  computed
# Chunk  492  computed
# Chunk  493  computed
# Chunk  494  computed
# Chunk  495  computed
# Chunk  496  computed
# Chunk  497  computed
# Chunk  498  computed
# Chunk  499  computed
# Chunk  500  computed
# Chunk  501  computed
# Chunk  502  computed
# Chunk  503  computed
# Chunk  504  computed
# Chunk  505  computed
# Chunk  506  computed
# Chunk  507  computed
# Chunk  508  computed
# Chunk  509  computed
# Chunk  510  computed
# Chunk  511  computed
# Chunk  512  computed
# Analytical =  150.83917277659248
# Simulation =  66.03178
# Computing theta =  0.10999999999999997
# Chunk  1  computed
# Chunk  2  computed
# Chunk  3  computed
# Chunk  4  computed
# Chunk  5  computed
# Chunk  6  computed
# Chunk  7  computed
# Chunk  8  computed
# Chunk  9  computed
# Chunk  10  computed
# Chunk  11  computed
# Chunk  12  computed
# Chunk  13  computed
# Chunk  14  computed
# Chunk  15  computed
# Chunk  16  computed
# Chunk  17  computed
# Chunk  18  computed
# Chunk  19  computed
# Chunk  20  computed
# Chunk  21  computed
# Chunk  22  computed
# Chunk  23  computed
# Chunk  24  computed
# Chunk  25  computed
# Chunk  26  computed
# Chunk  27  computed
# Chunk  28  computed
# Chunk  29  computed
# Chunk  30  computed
# Chunk  31  computed
# Chunk  32  computed
# Chunk  33  computed
# Chunk  34  computed
# Chunk  35  computed
# Chunk  36  computed
# Chunk  37  computed
# Chunk  38  computed
# Chunk  39  computed
# Chunk  40  computed
# Chunk  41  computed
# Chunk  42  computed
# Chunk  43  computed
# Chunk  44  computed
# Chunk  45  computed
# Chunk  46  computed
# Chunk  47  computed
# Chunk  48  computed
# Chunk  49  computed
# Chunk  50  computed
# Chunk  51  computed
# Chunk  52  computed
# Chunk  53  computed
# Chunk  54  computed
# Chunk  55  computed
# Chunk  56  computed
# Chunk  57  computed
# Chunk  58  computed
# Chunk  59  computed
# Chunk  60  computed
# Chunk  61  computed
# Chunk  62  computed
# Chunk  63  computed
# Chunk  64  computed
# Chunk  65  computed
# Chunk  66  computed
# Chunk  67  computed
# Chunk  68  computed
# Chunk  69  computed
# Chunk  70  computed
# Chunk  71  computed
# Chunk  72  computed
# Chunk  73  computed
# Chunk  74  computed
# Chunk  75  computed
# Chunk  76  computed
# Chunk  77  computed
# Chunk  78  computed
# Chunk  79  computed
# Chunk  80  computed
# Chunk  81  computed
# Chunk  82  computed
# Chunk  83  computed
# Chunk  84  computed
# Chunk  85  computed
# Chunk  86  computed
# Chunk  87  computed
# Chunk  88  computed
# Chunk  89  computed
# Chunk  90  computed
# Chunk  91  computed
# Chunk  92  computed
# Chunk  93  computed
# Chunk  94  computed
# Chunk  95  computed
# Chunk  96  computed
# Chunk  97  computed
# Chunk  98  computed
# Chunk  99  computed
# Chunk  100  computed
# Chunk  101  computed
# Chunk  102  computed
# Chunk  103  computed
# Chunk  104  computed
# Chunk  105  computed
# Chunk  106  computed
# Chunk  107  computed
# Chunk  108  computed
# Chunk  109  computed
# Chunk  110  computed
# Chunk  111  computed
# Chunk  112  computed
# Chunk  113  computed
# Chunk  114  computed
# Chunk  115  computed
# Chunk  116  computed
# Chunk  117  computed
# Chunk  118  computed
# Chunk  119  computed
# Chunk  120  computed
# Chunk  121  computed
# Chunk  122  computed
# Chunk  123  computed
# Chunk  124  computed
# Chunk  125  computed
# Chunk  126  computed
# Chunk  127  computed
# Chunk  128  computed
# Chunk  129  computed
# Chunk  130  computed
# Chunk  131  computed
# Chunk  132  computed
# Chunk  133  computed
# Chunk  134  computed
# Chunk  135  computed
# Chunk  136  computed
# Chunk  137  computed
# Chunk  138  computed
# Chunk  139  computed
# Chunk  140  computed
# Chunk  141  computed
# Chunk  142  computed
# Chunk  143  computed
# Chunk  144  computed
# Chunk  145  computed
# Chunk  146  computed
# Chunk  147  computed
# Chunk  148  computed
# Chunk  149  computed
# Chunk  150  computed
# Chunk  151  computed
# Chunk  152  computed
# Chunk  153  computed
# Chunk  154  computed
# Chunk  155  computed
# Chunk  156  computed
# Chunk  157  computed
# Chunk  158  computed
# Chunk  159  computed
# Chunk  160  computed
# Chunk  161  computed
# Chunk  162  computed
# Chunk  163  computed
# Chunk  164  computed
# Chunk  165  computed
# Chunk  166  computed
# Chunk  167  computed
# Chunk  168  computed
# Chunk  169  computed
# Chunk  170  computed
# Chunk  171  computed
# Chunk  172  computed
# Chunk  173  computed
# Chunk  174  computed
# Chunk  175  computed
# Chunk  176  computed
# Chunk  177  computed
# Chunk  178  computed
# Chunk  179  computed
# Chunk  180  computed
# Chunk  181  computed
# Chunk  182  computed
# Chunk  183  computed
# Chunk  184  computed
# Chunk  185  computed
# Chunk  186  computed
# Chunk  187  computed
# Chunk  188  computed
# Chunk  189  computed
# Chunk  190  computed
# Chunk  191  computed
# Chunk  192  computed
# Chunk  193  computed
# Chunk  194  computed
# Chunk  195  computed
# Chunk  196  computed
# Chunk  197  computed
# Chunk  198  computed
# Chunk  199  computed
# Chunk  200  computed
# Chunk  201  computed
# Chunk  202  computed
# Chunk  203  computed
# Chunk  204  computed
# Chunk  205  computed
# Chunk  206  computed
# Chunk  207  computed
# Chunk  208  computed
# Chunk  209  computed
# Chunk  210  computed
# Chunk  211  computed
# Chunk  212  computed
# Chunk  213  computed
# Chunk  214  computed
# Chunk  215  computed
# Chunk  216  computed
# Chunk  217  computed
# Chunk  218  computed
# Chunk  219  computed
# Chunk  220  computed
# Chunk  221  computed
# Chunk  222  computed
# Chunk  223  computed
# Chunk  224  computed
# Chunk  225  computed
# Chunk  226  computed
# Chunk  227  computed
# Chunk  228  computed
# Chunk  229  computed
# Chunk  230  computed
# Chunk  231  computed
# Chunk  232  computed
# Chunk  233  computed
# Chunk  234  computed
# Chunk  235  computed
# Chunk  236  computed
# Chunk  237  computed
# Chunk  238  computed
# Chunk  239  computed
# Chunk  240  computed
# Chunk  241  computed
# Chunk  242  computed
# Chunk  243  computed
# Chunk  244  computed
# Chunk  245  computed
# Chunk  246  computed
# Chunk  247  computed
# Chunk  248  computed
# Chunk  249  computed
# Chunk  250  computed
# Chunk  251  computed
# Chunk  252  computed
# Chunk  253  computed
# Chunk  254  computed
# Chunk  255  computed
# Chunk  256  computed
# Chunk  257  computed
# Chunk  258  computed
# Chunk  259  computed
# Chunk  260  computed
# Chunk  261  computed
# Chunk  262  computed
# Chunk  263  computed
# Chunk  264  computed
# Chunk  265  computed
# Chunk  266  computed
# Chunk  267  computed
# Chunk  268  computed
# Chunk  269  computed
# Chunk  270  computed
# Chunk  271  computed
# Chunk  272  computed
# Chunk  273  computed
# Chunk  274  computed
# Chunk  275  computed
# Chunk  276  computed
# Chunk  277  computed
# Chunk  278  computed
# Chunk  279  computed
# Chunk  280  computed
# Chunk  281  computed
# Chunk  282  computed
# Chunk  283  computed
# Chunk  284  computed
# Chunk  285  computed
# Chunk  286  computed
# Chunk  287  computed
# Chunk  288  computed
# Chunk  289  computed
# Chunk  290  computed
# Chunk  291  computed
# Chunk  292  computed
# Chunk  293  computed
# Chunk  294  computed
# Chunk  295  computed
# Chunk  296  computed
# Chunk  297  computed
# Chunk  298  computed
# Chunk  299  computed
# Chunk  300  computed
# Chunk  301  computed
# Chunk  302  computed
# Chunk  303  computed
# Chunk  304  computed
# Chunk  305  computed
# Chunk  306  computed
# Chunk  307  computed
# Chunk  308  computed
# Chunk  309  computed
# Chunk  310  computed
# Chunk  311  computed
# Chunk  312  computed
# Chunk  313  computed
# Chunk  314  computed
# Chunk  315  computed
# Chunk  316  computed
# Chunk  317  computed
# Chunk  318  computed
# Chunk  319  computed
# Chunk  320  computed
# Chunk  321  computed
# Chunk  322  computed
# Chunk  323  computed
# Chunk  324  computed
# Chunk  325  computed
# Chunk  326  computed
# Chunk  327  computed
# Chunk  328  computed
# Chunk  329  computed
# Chunk  330  computed
# Chunk  331  computed
# Chunk  332  computed
# Chunk  333  computed
# Chunk  334  computed
# Chunk  335  computed
# Chunk  336  computed
# Chunk  337  computed
# Chunk  338  computed
# Chunk  339  computed
# Chunk  340  computed
# Chunk  341  computed
# Chunk  342  computed
# Chunk  343  computed
# Chunk  344  computed
# Chunk  345  computed
# Chunk  346  computed
# Chunk  347  computed
# Chunk  348  computed
# Chunk  349  computed
# Chunk  350  computed
# Chunk  351  computed
# Chunk  352  computed
# Chunk  353  computed
# Chunk  354  computed
# Chunk  355  computed
# Chunk  356  computed
# Chunk  357  computed
# Chunk  358  computed
# Chunk  359  computed
# Chunk  360  computed
# Chunk  361  computed
# Chunk  362  computed
# Chunk  363  computed
# Chunk  364  computed
# Chunk  365  computed
# Chunk  366  computed
# Chunk  367  computed
# Chunk  368  computed
# Chunk  369  computed
# Chunk  370  computed
# Chunk  371  computed
# Chunk  372  computed
# Chunk  373  computed
# Chunk  374  computed
# Chunk  375  computed
# Chunk  376  computed
# Chunk  377  computed
# Chunk  378  computed
# Chunk  379  computed
# Chunk  380  computed
# Chunk  381  computed
# Chunk  382  computed
# Chunk  383  computed
# Chunk  384  computed
# Chunk  385  computed
# Chunk  386  computed
# Chunk  387  computed
# Chunk  388  computed
# Chunk  389  computed
# Chunk  390  computed
# Chunk  391  computed
# Chunk  392  computed
# Chunk  393  computed
# Chunk  394  computed
# Chunk  395  computed
# Chunk  396  computed
# Chunk  397  computed
# Chunk  398  computed
# Chunk  399  computed
# Chunk  400  computed
# Chunk  401  computed
# Chunk  402  computed
# Chunk  403  computed
# Chunk  404  computed
# Chunk  405  computed
# Chunk  406  computed
# Chunk  407  computed
# Chunk  408  computed
# Chunk  409  computed
# Chunk  410  computed
# Chunk  411  computed
# Chunk  412  computed
# Chunk  413  computed
# Chunk  414  computed
# Chunk  415  computed
# Chunk  416  computed
# Chunk  417  computed
# Chunk  418  computed
# Chunk  419  computed
# Chunk  420  computed
# Chunk  421  computed
# Chunk  422  computed
# Chunk  423  computed
# Chunk  424  computed
# Chunk  425  computed
# Chunk  426  computed
# Chunk  427  computed
# Chunk  428  computed
# Chunk  429  computed
# Chunk  430  computed
# Chunk  431  computed
# Chunk  432  computed
# Chunk  433  computed
# Chunk  434  computed
# Chunk  435  computed
# Chunk  436  computed
# Chunk  437  computed
# Chunk  438  computed
# Chunk  439  computed
# Chunk  440  computed
# Chunk  441  computed
# Chunk  442  computed
# Chunk  443  computed
# Chunk  444  computed
# Chunk  445  computed
# Chunk  446  computed
# Chunk  447  computed
# Chunk  448  computed
# Chunk  449  computed
# Chunk  450  computed
# Chunk  451  computed
# Chunk  452  computed
# Chunk  453  computed
# Chunk  454  computed
# Chunk  455  computed
# Chunk  456  computed
# Chunk  457  computed
# Chunk  458  computed
# Chunk  459  computed
# Chunk  460  computed
# Chunk  461  computed
# Chunk  462  computed
# Chunk  463  computed
# Chunk  464  computed
# Chunk  465  computed
# Chunk  466  computed
# Chunk  467  computed
# Chunk  468  computed
# Chunk  469  computed
# Chunk  470  computed
# Chunk  471  computed
# Chunk  472  computed
# Chunk  473  computed
# Chunk  474  computed
# Chunk  475  computed
# Chunk  476  computed
# Chunk  477  computed
# Chunk  478  computed
# Chunk  479  computed
# Chunk  480  computed
# Chunk  481  computed
# Chunk  482  computed
# Chunk  483  computed
# Chunk  484  computed
# Chunk  485  computed
# Chunk  486  computed
# Chunk  487  computed
# Chunk  488  computed
# Chunk  489  computed
# Chunk  490  computed
# Chunk  491  computed
# Chunk  492  computed
# Chunk  493  computed
# Chunk  494  computed
# Chunk  495  computed
# Chunk  496  computed
# Chunk  497  computed
# Chunk  498  computed
# Chunk  499  computed
# Chunk  500  computed
# Chunk  501  computed
# Chunk  502  computed
# Chunk  503  computed
# Chunk  504  computed
# Chunk  505  computed
# Chunk  506  computed
# Chunk  507  computed
# Chunk  508  computed
# Chunk  509  computed
# Chunk  510  computed
# Chunk  511  computed
# Chunk  512  computed
# Analytical =  194.23652052856096
# Simulation =  54.783916

# %%
F_INOUT = .0 * Theta
for th in range(len(Theta)):
    F_INOUT[th] = sis.F_in_out(Theta[th])

THETA_1 = np.linspace(0.01, 0.12, 128)
F_INOUT_1 = .0 * THETA_1
Fp_an = THETA_1 * .0
for th in range(len(THETA_1)):
    Fp_an[th] = np.real(fasit2Ncdiagint(sis.t, sis.omega*THETA_1[th], 0, sis.z, sis.omega, sis.Omega, sis.qhat))
    F_INOUT_1[th] = sis.F_in_out(THETA_1[th])

plt.plot(THETA_1, THETA_1**2 / 2 * Fp_an, color = "blue", label = "Analytical")
plt.plot(Theta, Theta**2 / 2 * Fp_sim, "o", markersize = 2, color = "red", label = "Simulation")
plt.ylabel(r"$F_{med}^{in-in}$")
plt.xlabel(r"$\theta$")
plt.title(r"$E = 100$ GeV, z = $0.3$, $\hat{q} = 1.5$ GeV$^2$/fm")
plt.legend()
plt.show()

plt.plot(THETA_1, THETA_1**2 / 2 * Fp_an + F_INOUT_1, color = "blue", label = "Analytical")
plt.plot(Theta, Theta**2 / 2 * Fp_sim + F_INOUT, "o", markersize = 2, color = "red", label = "Simulation")
plt.ylabel(r"$F_{med}$")
plt.xlabel(r"$\theta$")
plt.title(r"$E = 100$ GeV, z = $0.3$, $\hat{q} = 1.5$ GeV$^2$")
plt.legend()

# %%
print(sis.beta(sis.t))
# Out:
# 5.730552099987822
