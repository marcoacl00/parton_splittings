# %%
import numpy as np
import cupy as cp
from parton_splittings_gpu import *

# %%
sis = phsys(10, 0.5, 1.5, 2) #E, z, qF, Medium size (grid)
sis.set_dim(32,32,32,32) #Grid dimensions
sis.init_fsol()
ht = 0.01 #time step

simul = simulate(sis, ht, 2, 10)
# Out:
# Processing t =  0.05
# First nHom computed
# Faber params: lamb =  904.61426 gamma0 =  (0.034934282+0.06385882j) gamma1 =  0.6432849
# Number of polynomials =  10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 sis.init_fsol()
#       4 ht = 0.01 #time step
# ----> 6 simul = simulate(sis, ht, 2, 10)
#
# File ~/Workstation/Jet_Quenching/parton_splittings/parton_splittings_gpu/simulator.py:48, in simulate(sist, ht, t_L, step_save)
#      44 nFsol[1, 1:-1, 1:-1, 1:-1, 1:-1] +=  nHom * ht / 2
#      46 sis.set_fsol(nFsol)
# ---> 48 f_sol_n = faber_expand(sis, ht)
#      50 #Build non homogneous term at t = sis.t + ht
#      51 nHom = sis.source_term_gpu(sis.t)
#
# File ~/Workstation/Jet_Quenching/parton_splittings/parton_splittings_gpu/faber.py:89, in faber_expand(sys, ht)
#      86 print("Number of polynomials = ", m)
#      87 fH_0 = 1.0 * sys.Fsol
# ...

# %%
fsol = sis.Fsol.get()

# %%
np.save("fsol.npy", fsol)

# %%
print(fsol)
# Out:
# [[[[[ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     ...
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
# ...
