# %%
import numpy as np
import cupy as cp
from parton_splittings_gpu import *

# %%
sis = phsys(10, 0.5, 1.5, 3) #E, z, qF, Medium size (grid)
sis.set_dim(128,64,64,64) #Grid dimensions
sis.init_fsol()
ht = 0.01 #time step32

simul = simulate(sis, ht, 2, 100)
# Out:
# Processing t =  0.01
# First nHom computed
# Faber params: lamb =  12769.163 gamma0 =  (-0.2267343+0.004523991j) gamma1 =  0.8458846
# Number of polynomials =  159
# Polynomials processed
# Second nHom computed
# 0.015
# Processing t =  0.015
# First nHom computed
# Faber params: lamb =  8573.716 gamma0 =  (-0.22966717+0.0067377565j) gamma1 =  0.83773214
# Number of polynomials =  111
# Polynomials processed
# Second nHom computed
# 0.02
# Processing t =  0.02
# First nHom computed
# Faber params: lamb =  6471.614 gamma0 =  (-0.23370406+0.008926304j) gamma1 =  0.82981384
# Number of polynomials =  87
# Polynomials processed
# Second nHom computed
# 0.025
# Processing t =  0.025
# First nHom computed
# Faber params: lamb =  5104.8906 gamma0 =  (-0.2817421+0.011316129j) gamma1 =  0.8197317
# Number of polynomials =  72
# Polynomials processed
# Second nHom computed
# 0.030000000000000002
# Processing t =  0.030000000000000002
# First nHom computed
# ...

# %%
fsol = sis.Fsol.get()

# %%
np.save("fsol.npy", fsol)

# %%
print(fsol)
# Out:
# [[[[[ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     ...
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j ...
#       0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#       0.00000000e+00+0.00000000e+00j]
#     [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
# ...
